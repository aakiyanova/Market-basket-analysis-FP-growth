# %% [markdown]
# #### Modeling and Analysis

# %%
import pandas as pd
import numpy as np
from fpgrowth_py import fpgrowth
import pyfpgrowth
import random
import matplotlib.pyplot as plt
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import fpgrowth

# %%
# reading aisles dataset
aisles = pd.read_csv('data/aisles.csv')

# %%
# reading department dataset
department = pd.read_csv('data/departments.csv')

# %%
p = 0.10
all_orders = pd.read_csv('data/orders_train_prior.csv', header = 0, skiprows = lambda i: i>0 and random.random() > p)

# %%
all_orders_full = pd.read_csv('data/orders_train_prior.csv')

# %%
morning_orders = pd.read_csv('data/morning_orders.csv')

# %%
daytime_orders = pd.read_csv('data/day_orders.csv')

# %%
evening_orders = pd.read_csv('data/evening_orders.csv')

# %% [markdown]
# **Morning Orders**

# %%
# group products by order_id into a df
df_morning = morning_orders.groupby('order_id')['product_name'].agg([('product_name', ','.join)]).reset_index()

# %%
# change order_id column into an index
df_morning.set_index('order_id', inplace = True)

# %%
df_morning_split = df_morning.product_name.apply(lambda x: x.split(','))

# %%
df_morning_split.head()
# Out:
# order_id
# 174              [organic garlic, island vanilla cereal]
# 217                     [organic short grain brown rice]
# 521                                       [spring water]
# 598                                [breaded fish sticks]
# 750    [multi-seeds cracker, wheat gluten free waffle...
# Name: product_name, dtype: object

# %%
df_morning_orders = pd.DataFrame(df_morning_split)

# %%
df_morning_orders.head()
# Out:
#                                                product_name
# order_id
# 174                 [organic garlic, island vanilla cereal]
# 217                        [organic short grain brown rice]
# 521                                          [spring water]
# 598                                   [breaded fish sticks]
# 750       [multi-seeds cracker, wheat gluten free waffle...

# %%
df_morning.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16460 entries, 174 to 3421049
# Data columns (total 1 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product_name  16460 non-null  object
# dtypes: object(1)
# memory usage: 257.2+ KB

# %%
df_morning_orders.shape
# Out:
# (16460, 1)

# %%
patterns = pyfpgrowth.find_frequent_patterns(df_morning_orders['product_name'], 50)

# %%
patterns
# Out:
# {('organic broccoli',): 50,
#  ('clementines bag',): 50,
#  ('unsalted butter',): 51,
#  ('clementines',): 51,
#  ('uncured genoa salami',): 52,
#  ('sparkling natural mineral water',): 53,
#  ('extra virgin olive oil',): 54,
#  ('boneless skinless chicken breasts',): 54,
#  ('bunched cilantro',): 55,
#  ('red vine tomato',): 58,
#  ('organic garnet sweet potato (yam)',): 58,
#  ("organic d'anjou pears",): 58,
#  ('organic reduced fat 2% milk',): 61,
#  ('organic kiwi',): 62,
#  ('lime sparkling water',): 62,
#  ('organic red bell pepper',): 62,
#  ('hass avocados',): 63,
#  ('unsweetened almondmilk',): 64,
#  ('organic italian parsley bunch',): 64,
#  ('organic navel orange',): 65,
#  ('small hass avocado',): 65,
#  ('blueberries',): 66,
#  ('carrots',): 67,
#  ('organic ginger root',): 67,
#  ('organic peeled whole baby carrots',): 67,
#  ('michigan organic kale',): 67,
#  ('organic small bunch celery',): 68,
#  ('100% whole wheat bread',): 68,
#  ('organic unsweetened almond milk',): 69,
#  ('organic granny smith apple',): 69,
#  ('green bell pepper',): 71,
#  ('organic tomato cluster',): 72,
#  ('organic baby arugula',): 73,
#  ('broccoli crown',): 74,
#  ('spring water',): 77,
#  ('organic half & half',): 78,
#  ('organic large extra fancy fuji apple',): 82,
#  ('apple honeycrisp organic',): 82,
#  ('organic baby carrots',): 82,
#  ('red peppers',): 83,
#  ('yellow onions',): 83,
#  ('raspberries',): 84,
#  ('organic whole string cheese',): 85,
#  ('half & half',): 86,
#  ('sparkling water grapefruit',): 88,
#  ('organic blackberries',): 88,
#  ('cucumber kirby',): 88,
#  ('organic cilantro',): 90,
#  ('fresh cauliflower',): 90,
#  ('organic grape tomatoes',): 91,
#  ('organic fuji apple',): 94,
#  ('original hummus',): 94,
#  ('asparagus',): 94,
#  ('organic red onion',): 99,
#  ('honeycrisp apple',): 103,
#  ('organic gala apples',): 104,
#  ('organic lemon',): 107,
#  ('organic zucchini',): 111,
#  ('organic garlic',): 113,
#  ('organic yellow onion',): 119,
#  ('organic cucumber',): 123,
#  ('seedless red grapes',): 124,
#  ('organic blueberries',): 126,
#  ('limes',): 150,
#  ('organic whole milk',): 153,
#  ('organic raspberries',): 165,
#  ('strawberries',): 167,
#  ('large lemon',): 184,
#  ('organic avocado',): 188,
#  ('organic hass avocado',): 211,
#  ('organic baby spinach',): 261,
#  ('organic strawberries',): 286,
#  ('bag of organic bananas', 'organic strawberries'): 52,
#  ('bag of organic bananas',): 498,
#  ('banana',): 538}

# %%
rules = pyfpgrowth.generate_association_rules(patterns, 0.01)

# %%
rules
# Out:
# {('bag of organic bananas',): (('organic strawberries',), 0.10441767068273092),
#  ('organic strawberries',): (('bag of organic bananas',), 0.18181818181818182)}

# %% [markdown]
# **Daytime orders**

# %%
# group products by order_id into a df
df_daytime = daytime_orders.groupby('order_id')['product_name'].agg([('product_name', ','.join)]).reset_index()

# %%
# change order_id column into an index
df_daytime.set_index('order_id', inplace = True)

# %%
df_daytime_split = df_daytime.product_name.apply(lambda x: x.split(','))

# %%
df_daytime_split.head()
# Out:
# order_id
# 254                               [organic strawberries]
# 360                                  [shiitake mushroom]
# 470                         [sparkling water grapefruit]
# 729             [special k chocolatey strawberry cereal]
# 762    [organic strawberries, celery hearts, organic ...
# Name: product_name, dtype: object

# %%
df_daytime_orders = pd.DataFrame(df_daytime_split)

# %%
df_daytime_orders.shape
# Out:
# (29208, 1)

# %%
patterns_daytime = pyfpgrowth.find_frequent_patterns(df_daytime_orders['product_name'], 50)

# %%
patterns_daytime
# Out:
# {('organic medium salsa',): 50,
#  ('baby spinach',): 50,
#  ('creamy peanut butter',): 50,
#  ('organic creamy peanut butter',): 50,
#  ('ground turkey breast',): 50,
#  ('organic coconut milk',): 51,
#  ('organic heavy whipping cream',): 51,
#  ('organic white onions',): 51,
#  ('hass avocado',): 51,
#  ('sour cream',): 53,
#  ('cantaloupe',): 53,
#  ('organic bread with 21 whole grains',): 53,
#  ('total 0% greek yogurt',): 54,
#  ('organic broccoli crowns',): 54,
#  ('gala apples',): 55,
#  ('unsweetened vanilla almond milk',): 55,
#  ('frozen organic wild blueberries',): 55,
#  ('fat free milk',): 55,
#  ('boneless skinless chicken breast',): 55,
#  ('uncured hickory smoked sunday bacon',): 55,
#  ('100% raw coconut water',): 57,
#  ('pineapple chunks',): 57,
#  ('shredded mild cheddar cheese',): 57,
#  ('total 2% with strawberry lowfat greek strained yogurt',): 57,
#  ('organic red radish bunch',): 57,
#  ('organic reduced fat milk',): 58,
#  ('lightly salted baked snap pea crisps',): 58,
#  ('2% reduced fat milk',): 58,
#  ('organic sticks low moisture part skim mozzarella string cheese',): 58,
#  ('organic celery hearts',): 58,
#  ('organic basil',): 58,
#  ('brussels sprouts',): 58,
#  ('organic fat free milk',): 59,
#  ('yellow bell pepper',): 59,
#  ('fresh ginger root',): 59,
#  ('organic garbanzo beans',): 60,
#  ('organic milk',): 61,
#  ('organic extra firm tofu',): 61,
#  ('no salt added black beans',): 61,
#  ('clementines',): 62,
#  ('original orange juice',): 62,
#  ('organic large brown grade aa cage free eggs',): 63,
#  ('soda',): 63,
#  ('green beans',): 63,
#  ('italian sparkling mineral water',): 63,
#  ('bartlett pears',): 64,
#  ('honey nut cheerios',): 64,
#  ('romaine hearts',): 65,
#  ('organic romaine lettuce',): 66,
#  ('organic bartlett pear',): 66,
#  ('vanilla almond breeze almond milk',): 66,
#  ('organic roma tomato',): 67,
#  ('organic russet potato',): 68,
#  ('red raspberries',): 68,
#  ('unsweetened original almond breeze almond milk',): 69,
#  ('pure irish butter',): 70,
#  ('pure sparkling water',): 71,
#  ('sharp cheddar cheese',): 72,
#  ('organic black beans',): 72,
#  ('clementines bag',): 73,
#  ('whole milk',): 73,
#  ('organic whole strawberries',): 74,
#  ('green onions',): 75,
#  ('red onion',): 75,
#  ('granny smith apples',): 76,
#  ('sparkling natural mineral water',): 76,
#  ('extra virgin olive oil',): 77,
#  ('organic broccoli florets',): 77,
#  ('organic baby broccoli',): 78,
#  ('shredded parmesan',): 80,
#  ('organic carrot bunch',): 81,
#  ('russet potato',): 81,
#  ('unsalted butter',): 82,
#  ('organic spring mix',): 82,
#  ('organic lacinato (dinosaur) kale',): 84,
#  ('grape white/green seedless',): 84,
#  ('organic reduced fat 2% milk',): 84,
#  ('organic kiwi',): 86,
#  ('orange bell pepper',): 87,
#  ("organic d'anjou pears",): 87,
#  ('organic grade a free range large brown eggs',): 88,
#  ('organic ginger root',): 89,
#  ('organic banana',): 89,
#  ('sparkling lemon water',): 90,
#  ('large alfresco eggs',): 91,
#  ('feta cheese crumbles',): 92,
#  ('grated parmesan',): 93,
#  ('organic broccoli',): 95,
#  ('garlic',): 96,
#  ('organic whole string cheese',): 99,
#  ('uncured genoa salami',): 101,
#  ('spring water',): 102,
#  ('unsweetened almondmilk',): 102,
#  ('bunched cilantro',): 103,
#  ('roma tomato',): 103,
#  ('jalapeno peppers',): 106,
#  ('organic navel orange',): 107,
#  ('red vine tomato',): 108,
#  ('organic italian parsley bunch',): 108,
#  ('blueberries',): 108,
#  ('organic tomato cluster',): 112,
#  ('organic unsweetened almond milk',): 113,
#  ('hass avocados',): 113,
#  ('lime sparkling water',): 114,
#  ('organic red bell pepper',): 115,
#  ('organic granny smith apple',): 116,
#  ('boneless skinless chicken breasts',): 124,
#  ('organic garnet sweet potato (yam)',): 125,
#  ('organic peeled whole baby carrots',): 127,
#  ('raspberries',): 127,
#  ('original hummus',): 127,
#  ('half & half',): 133,
#  ('100% whole wheat bread',): 134,
#  ('michigan organic kale',): 135,
#  ('organic gala apples',): 136,
#  ('organic blackberries',): 138,
#  ('green bell pepper',): 139,
#  ('broccoli crown',): 141,
#  ('fresh cauliflower',): 142,
#  ('red peppers',): 147,
#  ('carrots',): 148,
#  ('organic small bunch celery',): 152,
#  ('small hass avocado',): 154,
#  ('organic large extra fancy fuji apple',): 156,
#  ('honeycrisp apple',): 156,
#  ('organic half & half',): 157,
#  ('apple honeycrisp organic',): 159,
#  ('organic baby arugula',): 159,
#  ('organic cilantro',): 164,
#  ('seedless red grapes',): 171,
#  ('organic fuji apple',): 172,
#  ('organic red onion',): 172,
#  ('asparagus',): 179,
#  ('organic lemon',): 179,
#  ('organic grape tomatoes',): 181,
#  ('organic baby carrots',): 182,
#  ('sparkling water grapefruit',): 184,
#  ('yellow onions',): 184,
#  ('cucumber kirby',): 186,
#  ('organic cucumber',): 203,
#  ('organic garlic',): 231,
#  ('organic yellow onion',): 235,
#  ('organic zucchini',): 245,
#  ('organic blueberries',): 246,
#  ('organic whole milk',): 269,
#  ('limes',): 308,
#  ('strawberries',): 321,
#  ('organic raspberries',): 327,
#  ('bag of organic bananas', 'organic raspberries'): 50,
#  ('large lemon',): 375,
#  ('banana', 'large lemon'): 60,
#  ('organic hass avocado',): 393,
#  ('bag of organic bananas', 'organic hass avocado'): 67,
#  ('organic avocado',): 403,
#  ('banana', 'organic avocado'): 60,
#  ('organic baby spinach',): 516,
#  ('bag of organic bananas', 'organic baby spinach'): 62,
#  ('banana', 'organic strawberries'): 56,
#  ('bag of organic bananas', 'organic strawberries'): 79,
#  ('bag of organic bananas',): 803,
#  ('banana',): 975}

# %%
rules = pyfpgrowth.generate_association_rules(patterns_daytime, 0.01)

# %%
rules
# Out:
# {('bag of organic bananas',): (('organic strawberries',), 0.09838107098381071),
#  ('organic raspberries',): (('bag of organic bananas',), 0.1529051987767584),
#  ('banana',): (('organic strawberries',), 0.057435897435897436),
#  ('large lemon',): (('banana',), 0.16),
#  ('organic hass avocado',): (('bag of organic bananas',), 0.17048346055979643),
#  ('organic avocado',): (('banana',), 0.1488833746898263),
#  ('organic baby spinach',): (('bag of organic bananas',), 0.12015503875968993)}

# %% [markdown]
# **Evening Orders**

# %%
# group products by order_id into a df
df_evening = evening_orders.groupby('order_id')['product_name'].agg([('product_name', ','.join)]).reset_index()

# %%
# change order_id column into an index
df_evening.set_index('order_id', inplace = True)

# %%
df_evening_split = df_evening.product_name.apply(lambda x: x.split(','))

# %%
df_evening_split.head()
# Out:
# order_id
# 527     [organic jalapeno pepper, flat fillets anchovies]
# 1700    [organic classic rich crackers, strawberry fla...
# 2032               [raspberry blackberry sparkling water]
# 2458    [frozen organic wild blueberries, organic lemo...
# 2468    [original/ranch/bbq/chile picante con limon va...
# Name: product_name, dtype: object

# %%
df_evening_orders = pd.DataFrame(df_evening_split)

# %%
df_evening_orders.shape
# Out:
# (7704, 1)

# %%
patterns_evening = pyfpgrowth.find_frequent_patterns(df_evening_orders['product_name'], 30)

# %%
patterns_daytime
# Out:
# {('organic medium salsa',): 50,
#  ('baby spinach',): 50,
#  ('creamy peanut butter',): 50,
#  ('organic creamy peanut butter',): 50,
#  ('ground turkey breast',): 50,
#  ('organic coconut milk',): 51,
#  ('organic heavy whipping cream',): 51,
#  ('organic white onions',): 51,
#  ('hass avocado',): 51,
#  ('sour cream',): 53,
#  ('cantaloupe',): 53,
#  ('organic bread with 21 whole grains',): 53,
#  ('total 0% greek yogurt',): 54,
#  ('organic broccoli crowns',): 54,
#  ('gala apples',): 55,
#  ('unsweetened vanilla almond milk',): 55,
#  ('frozen organic wild blueberries',): 55,
#  ('fat free milk',): 55,
#  ('boneless skinless chicken breast',): 55,
#  ('uncured hickory smoked sunday bacon',): 55,
#  ('100% raw coconut water',): 57,
#  ('pineapple chunks',): 57,
#  ('shredded mild cheddar cheese',): 57,
#  ('total 2% with strawberry lowfat greek strained yogurt',): 57,
#  ('organic red radish bunch',): 57,
#  ('organic reduced fat milk',): 58,
#  ('lightly salted baked snap pea crisps',): 58,
#  ('2% reduced fat milk',): 58,
#  ('organic sticks low moisture part skim mozzarella string cheese',): 58,
#  ('organic celery hearts',): 58,
#  ('organic basil',): 58,
#  ('brussels sprouts',): 58,
#  ('organic fat free milk',): 59,
#  ('yellow bell pepper',): 59,
#  ('fresh ginger root',): 59,
#  ('organic garbanzo beans',): 60,
#  ('organic milk',): 61,
#  ('organic extra firm tofu',): 61,
#  ('no salt added black beans',): 61,
#  ('clementines',): 62,
#  ('original orange juice',): 62,
#  ('organic large brown grade aa cage free eggs',): 63,
#  ('soda',): 63,
#  ('green beans',): 63,
#  ('italian sparkling mineral water',): 63,
#  ('bartlett pears',): 64,
#  ('honey nut cheerios',): 64,
#  ('romaine hearts',): 65,
#  ('organic romaine lettuce',): 66,
#  ('organic bartlett pear',): 66,
#  ('vanilla almond breeze almond milk',): 66,
#  ('organic roma tomato',): 67,
#  ('organic russet potato',): 68,
#  ('red raspberries',): 68,
#  ('unsweetened original almond breeze almond milk',): 69,
#  ('pure irish butter',): 70,
#  ('pure sparkling water',): 71,
#  ('sharp cheddar cheese',): 72,
#  ('organic black beans',): 72,
#  ('clementines bag',): 73,
#  ('whole milk',): 73,
#  ('organic whole strawberries',): 74,
#  ('green onions',): 75,
#  ('red onion',): 75,
#  ('granny smith apples',): 76,
#  ('sparkling natural mineral water',): 76,
#  ('extra virgin olive oil',): 77,
#  ('organic broccoli florets',): 77,
#  ('organic baby broccoli',): 78,
#  ('shredded parmesan',): 80,
#  ('organic carrot bunch',): 81,
#  ('russet potato',): 81,
#  ('unsalted butter',): 82,
#  ('organic spring mix',): 82,
#  ('organic lacinato (dinosaur) kale',): 84,
#  ('grape white/green seedless',): 84,
#  ('organic reduced fat 2% milk',): 84,
#  ('organic kiwi',): 86,
#  ('orange bell pepper',): 87,
#  ("organic d'anjou pears",): 87,
#  ('organic grade a free range large brown eggs',): 88,
#  ('organic ginger root',): 89,
#  ('organic banana',): 89,
#  ('sparkling lemon water',): 90,
#  ('large alfresco eggs',): 91,
#  ('feta cheese crumbles',): 92,
#  ('grated parmesan',): 93,
#  ('organic broccoli',): 95,
#  ('garlic',): 96,
#  ('organic whole string cheese',): 99,
#  ('uncured genoa salami',): 101,
#  ('spring water',): 102,
#  ('unsweetened almondmilk',): 102,
#  ('bunched cilantro',): 103,
#  ('roma tomato',): 103,
#  ('jalapeno peppers',): 106,
#  ('organic navel orange',): 107,
#  ('red vine tomato',): 108,
#  ('organic italian parsley bunch',): 108,
#  ('blueberries',): 108,
#  ('organic tomato cluster',): 112,
#  ('organic unsweetened almond milk',): 113,
#  ('hass avocados',): 113,
#  ('lime sparkling water',): 114,
#  ('organic red bell pepper',): 115,
#  ('organic granny smith apple',): 116,
#  ('boneless skinless chicken breasts',): 124,
#  ('organic garnet sweet potato (yam)',): 125,
#  ('organic peeled whole baby carrots',): 127,
#  ('raspberries',): 127,
#  ('original hummus',): 127,
#  ('half & half',): 133,
#  ('100% whole wheat bread',): 134,
#  ('michigan organic kale',): 135,
#  ('organic gala apples',): 136,
#  ('organic blackberries',): 138,
#  ('green bell pepper',): 139,
#  ('broccoli crown',): 141,
#  ('fresh cauliflower',): 142,
#  ('red peppers',): 147,
#  ('carrots',): 148,
#  ('organic small bunch celery',): 152,
#  ('small hass avocado',): 154,
#  ('organic large extra fancy fuji apple',): 156,
#  ('honeycrisp apple',): 156,
#  ('organic half & half',): 157,
#  ('apple honeycrisp organic',): 159,
#  ('organic baby arugula',): 159,
#  ('organic cilantro',): 164,
#  ('seedless red grapes',): 171,
#  ('organic fuji apple',): 172,
#  ('organic red onion',): 172,
#  ('asparagus',): 179,
#  ('organic lemon',): 179,
#  ('organic grape tomatoes',): 181,
#  ('organic baby carrots',): 182,
#  ('sparkling water grapefruit',): 184,
#  ('yellow onions',): 184,
#  ('cucumber kirby',): 186,
#  ('organic cucumber',): 203,
#  ('organic garlic',): 231,
#  ('organic yellow onion',): 235,
#  ('organic zucchini',): 245,
#  ('organic blueberries',): 246,
#  ('organic whole milk',): 269,
#  ('limes',): 308,
#  ('strawberries',): 321,
#  ('organic raspberries',): 327,
#  ('bag of organic bananas', 'organic raspberries'): 50,
#  ('large lemon',): 375,
#  ('banana', 'large lemon'): 60,
#  ('organic hass avocado',): 393,
#  ('bag of organic bananas', 'organic hass avocado'): 67,
#  ('organic avocado',): 403,
#  ('banana', 'organic avocado'): 60,
#  ('organic baby spinach',): 516,
#  ('bag of organic bananas', 'organic baby spinach'): 62,
#  ('banana', 'organic strawberries'): 56,
#  ('bag of organic bananas', 'organic strawberries'): 79,
#  ('bag of organic bananas',): 803,
#  ('banana',): 975}

# %%
rules = pyfpgrowth.generate_association_rules(patterns_evening, 0.001)

# %%
rules
# Out:
# {}

# %% [markdown]
# **All Orders**

# %%
# group products by order_id into a df
df_all_orders = all_orders_full.groupby('order_id')['product_name'].agg([('product_name', ','.join)]).reset_index()

# %%
# reset order_id as index
df_all_orders.set_index('order_id', inplace=True)

# %%
# split results product sets by comma
df_orders_split = df_all_orders.product_name.apply(lambda x: x.split(','))

# %%
# create a dataframe
df_orders = pd.DataFrame(df_orders_split)

# %%
df_orders.head(2)
# Out:
#                                                product_name
# order_id
# 1         [organic celery hearts, organic 4% milk fat wh...
# 4         [tiny twists pretzels, chewy 25% low sugar cho...

# %%
df_orders.shape
# Out:
# (1305846, 1)

# %%
# Identify products with minimum support level
patterns_all = pyfpgrowth.find_frequent_patterns(df_orders['product_name'], 500)

# %%
patterns_all
# Out:
# {('original instant oatmeal',): 500,
#  ('chocolate sea salt',): 500,
#  ('sweet potato fries with sea salt',): 501,
#  ('black beans no salt added',): 502,
#  ('classic mix variety',): 502,
#  ('organic ezekiel 4:9 sesame bread',): 502,
#  ('organic yokids lemonade/blueberry variety pack yogurt squeezers tubes',): 502,
#  ('smartwater® electrolyte enhanced water',): 504,
#  ('hommus classic original',): 504,
#  ('uncured beef hot dogs',): 504,
#  ('vitamin water zero squeezed lemonade',): 505,
#  ('beer',): 505,
#  ('soft pretzel mini buns',): 505,
#  ('frozen peaches',): 505,
#  ('100% recycled bath tissue rolls',): 505,
#  ('mexican finely shredded cheese',): 505,
#  ('total 0% blueberry acai greek yogurt',): 506,
#  ('organic super fruit punch juice drink',): 506,
#  ('iced oatmeal cookie kid z bar',): 507,
#  ('ground buffalo',): 507,
#  ('hardwood smokedcenter cut original bacon',): 507,
#  ('organic string cheese',): 508,
#  ('tortillas corn organic',): 508,
#  ('red grapefruit',): 508,
#  ('chardonnay',): 509,
#  ('blueberry muffin bar',): 510,
#  ('smartwater electrolyte enhanced water',): 510,
#  ('tomatoes whole peeled',): 510,
#  ('low fat strawberry yogurt tubes',): 511,
#  ('honey wheat enriched bread',): 511,
#  ('classic potato chips',): 511,
#  ('all natural apricot sparkling water',): 511,
#  ('ancient grain original granola',): 512,
#  ('four cheese pasta sauce',): 513,
#  ('raspberry lemonade',): 513,
#  ('vitamin d milk',): 514,
#  ('small macintosh apple',): 514,
#  ('organic stoneground wheat crackers',): 516,
#  ('sliced baby bella mushrooms',): 518,
#  ('vanilla bean light ice cream',): 518,
#  ('turkey bacon',): 518,
#  ('thyme',): 519,
#  ('everything deli style pretzel crisps crackers',): 519,
#  ('pad thai',): 520,
#  ('new orleans iced coffee',): 520,
#  ('synergy organic & raw cosmic cranberry',): 521,
#  ('dried sweetened cranberries',): 521,
#  ('100% apple juice',): 521,
#  ('apple sauce',): 521,
#  ('flax plus organic pumpkin flax granola',): 522,
#  ('golden pineapple',): 522,
#  ('organic russet potato bag',): 523,
#  ('original beef jerky',): 523,
#  ('green cabbage',): 523,
#  ('frosted mini-wheats original cereal',): 524,
#  ('plain non-fat greek yogurt',): 525,
#  ('almondmilk creamer vanilla',): 525,
#  ('extra ginger brew jamaican style ginger beer',): 525,
#  ('lavender hand soap',): 526,
#  ('energy drink',): 526,
#  ('cherry pomegranate greek yogurt',): 526,
#  ('all purpose flour',): 527,
#  ('organic yellow mustard',): 527,
#  ('ezekiel 4:9 sprouted grain tortillas',): 527,
#  ('french vanilla coconut milk creamer',): 528,
#  ('minced garlic',): 528,
#  ('classic almond butter',): 529,
#  ('goo berry pie probugs kefir',): 530,
#  ('yokids squeeze! organic strawberry flavor yogurt',): 531,
#  ('fruit punch sports drink',): 532,
#  ('kumato tomatoes',): 532,
#  ('bread country buttermilk',): 533,
#  ('blueberry on the bottom nonfat greek yogurt',): 535,
#  ('mandarins bag',): 536,
#  ('ice cream sandwiches vanilla',): 536,
#  ('free & clear unscented baby wipes',): 537,
#  ('large pineapple chunks',): 537,
#  ('organic peeled & cooked beets',): 537,
#  ('meyer lemon',): 538,
#  ('lemon lime soda',): 538,
#  ('100% pure apple juice',): 538,
#  ('organic whole milk strawberry beet berry yogurt pouch',): 541,
#  ('whole white mushrooms',): 541,
#  ('sourdough baguette',): 541,
#  ('premium unsweetened iced tea',): 542,
#  ('baby portabella mushrooms',): 542,
#  ('classic hummus family size',): 543,
#  ('lemon verbena dish soap',): 543,
#  ('sweet rolls',): 543,
#  ('lacinato kale og',): 543,
#  ('classic soda',): 544,
#  ('organic shells and white cheddar',): 544,
#  ('cream top smooth & creamy vanilla yogurt',): 545,
#  ('half and half cream',): 545,
#  ('sparkling natural spring water',): 547,
#  ('grilled chicken breast',): 549,
#  ('peeled garlic',): 549,
#  ('vanilla blueberry clusters with flax seeds granola',): 549,
#  ('sweet cream salted butter',): 549,
#  ('cabernet sauvignon',): 550,
#  ('light sour cream',): 551,
#  ('yokids strawberry banana/strawberry yogurt',): 552,
#  ('organic spaghetti pasta',): 554,
#  ('cinnamon raisin bread',): 554,
#  ('strawberry rhubarb yogurt',): 554,
#  ('organic whole white mushrooms',): 554,
#  ('unsweetened almond milk',): 555,
#  ('goat cheese log',): 555,
#  ('blue cheese crumbles',): 557,
#  ('chicken broth',): 558,
#  ('diet ginger ale all natural soda',): 558,
#  ('organic tahini',): 560,
#  ('organic greek lowfat yogurt with strawberries',): 561,
#  ('freshly squeezed orange juice',): 561,
#  ('organic wheat square crackers',): 562,
#  ('avocado',): 562,
#  ('baby spinach salad',): 562,
#  ('unsalted cultured butter',): 563,
#  ('multigrain pita chips',): 563,
#  ('organic genoa salami',): 564,
#  ('organic strawana probugs kefir',): 564,
#  ('organic low sodium chicken cooking stock',): 564,
#  ('mache rosettes french salad mix',): 564,
#  ('bok choy',): 565,
#  ('soft pretzel burger buns',): 566,
#  ('wheat gluten free waffles',): 566,
#  ('organic cane sugar',): 566,
#  ('sparkling clementine juice',): 566,
#  ('gluten free peanut butter dark chocolate chewy with a crunch granola bars',): 567,
#  ('enlightened organic raw kombucha',): 569,
#  ("major dickason's blend ground coffee dark roast",): 569,
#  ('coconut yoghurt',): 570,
#  ('bosc pear',): 570,
#  ('100% grated parmesan cheese',): 571,
#  ('russet potatoes',): 571,
#  ('organic greek plain nonfat yogurt',): 572,
#  ('four cheese thin crust pizza',): 572,
#  ('original fresh stack crackers',): 573,
#  ('liquid egg whites',): 573,
#  ('white sandwich bread',): 573,
#  ('white peach',): 573,
#  ('premium original saltine crackers',): 577,
#  ('broccoli & apple stage 2 baby food',): 577,
#  ('garlic powder',): 578,
#  ('organic whole crimini mushrooms',): 578,
#  ('white sliced mushrooms',): 579,
#  ('jalapeno potato chips',): 579,
#  ('fresh asparagus',): 580,
#  ('peanut butter cereal',): 580,
#  ('organic raw multigreen kobmbucha',): 580,
#  ('organic greek nonfat yogurt with mixed berries',): 581,
#  ('strawberry ice cream',): 582,
#  ('medium salsa roja',): 584,
#  ('organic berry blend',): 585,
#  ('sweet baguette',): 587,
#  ('boneless and skinless chicken breast',): 587,
#  ('butterhead lettuce',): 587,
#  ('crackers harvest whole wheat',): 587,
#  ('mild diced green chiles',): 588,
#  ('lean ground turky',): 588,
#  ('organic dark sweet cherries',): 589,
#  ('canned aranciata orange',): 589,
#  ('california sourdough bread',): 592,
#  ('half baked® ice cream',): 592,
#  ('garlic couscous',): 593,
#  ('organic smoked turkey breast',): 593,
#  ('cold brew coffee double espresso with almond milk',): 594,
#  ('gluten free white sandwich bread',): 594,
#  ('naked green machine boosted juice smoothie',): 595,
#  ('organic yokids smoothie strawberry banana lowfat yogurt',): 597,
#  ('organic marinara pasta sauce',): 599,
#  ('fusilli no. 34',): 599,
#  ('salt & pepper krinkle chips',): 600,
#  ('stringless sugar snap peas',): 600,
#  ('americone dream® ice cream',): 600,
#  ('whole wheat english muffins',): 600,
#  ('mozzarella cheese',): 601,
#  ('organic cut green beans',): 601,
#  ('organic jasmine rice',): 601,
#  ('salted sweet cream butter',): 602,
#  ('bananas',): 603,
#  ('large burrito flour tortillas',): 603,
#  ('birthday cake light ice cream',): 604,
#  ('sweet potato tortilla chips',): 604,
#  ('whole grain oat cereal',): 605,
#  ('organic sprouted english muffin',): 606,
#  ('popcorn',): 606,
#  ('organic chicken noodle soup',): 606,
#  ('drinking water',): 609,
#  ('mini babybel light semisoft edam cheeses',): 609,
#  ('organic rolled oats',): 610,
#  ('fresh cut golden sweet whole kernel corn',): 610,
#  ('organic & raw strawberry serenity kombucha',): 610,
#  ('special reserve extra sharp cheddar cheese',): 611,
#  ('fat free blueberry yogurt',): 611,
#  ('organic mountain forest amber honey',): 614,
#  ('gluten free blueberry waffles',): 614,
#  ('organic green lentils',): 615,
#  ('supergreens!',): 617,
#  ('grade aa large white eggs',): 617,
#  ('roasted salted cashews',): 617,
#  ('gluten free spongebob spinach littles',): 618,
#  ('organic rainbow chard vegetable',): 618,
#  ('honey wheat bread',): 618,
#  ('organic mini sandwich crackers peanut butter',): 619,
#  ('organic chocolate chip chewy granola bars',): 619,
#  ('hazelnut spread with skim milk & cocoa',): 619,
#  ('organic whole wheat fusilli',): 619,
#  ('applewood smoked bacon',): 620,
#  ('coconut almond unsweetened creamer blend',): 622,
#  ('organic crushed fire roasted tomatoes',): 622,
#  ('mint chip',): 622,
#  ('organic broccoli crown',): 622,
#  ('florida orange juice with calcium & vitamin d',): 623,
#  ('organic penne rigate',): 623,
#  ('organic apple slices',): 623,
#  ('half and half',): 624,
#  ('coke zero',): 624,
#  ('yobaby organic plain yogurt',): 626,
#  ('poblano pepper',): 626,
#  ('original restaurant style tortilla chips',): 626,
#  ('pineapple',): 626,
#  ('low fat vanilla yogurt',): 627,
#  ('roasted garlic hummus',): 627,
#  ('cage free grade a large brown eggs',): 628,
#  ('penne rigate #41 pasta',): 628,
#  ('organic yokids very berry smoothies',): 628,
#  ('mineral water',): 629,
#  ('multigrain tortilla chips',): 629,
#  ('broccoli florets',): 630,
#  ('chicken pot pie',): 630,
#  ('bean & cheese burrito',): 631,
#  ('macaroni & cheese dinner original flavor',): 632,
#  ('monterey jack cheese',): 634,
#  ('sour cream & onion potato chips',): 636,
#  ('100% recycled bathroom tissue',): 636,
#  ('artichokes',): 639,
#  ('gourmet tomato medley',): 639,
#  ('peanut butter chocolate chip fruit & nut food bar',): 641,
#  ('yellow straightneck squash',): 641,
#  ('plantain chips',): 641,
#  ('thick & crispy tortilla chips',): 644,
#  ('cola soft drink',): 644,
#  ('angel hair pasta',): 645,
#  ('sea salt caramel gelato',): 645,
#  ('milk reduced fat 2% milkfat',): 645,
#  ('icelandic style fat free plain yogurt',): 646,
#  ('mixed berries whole milk icelandic style skyr yogurt',): 649,
#  ('purity farms ghee clarified butter',): 649,
#  ('organic sugar snap peas',): 649,
#  ('crispy wheat crackers',): 650,
#  ('club soda',): 651,
#  ('spinach peas & pear stage 2 baby food',): 651,
#  ('garnet sweet potato (yam)',): 652,
#  ('organic lactose free 1% lowfat milk',): 652,
#  ('90% lean ground beef',): 653,
#  ('white corn tortillas',): 653,
#  ('apple pie fruit & nut food bar',): 654,
#  ('shredded hash browns',): 655,
#  ('plain whole milk yogurt',): 655,
#  ('hot dog buns',): 655,
#  ('cheese pizza',): 657,
#  ('yukon gold potatoes 5lb bag',): 657,
#  ('yogurt lowfat strawberry',): 657,
#  ('peanut butter creamy with salt',): 658,
#  ('organic muenster cheese slices',): 658,
#  ('organic creamy tomato soup',): 659,
#  ('organic chicken thighs',): 660,
#  ('classic white bread',): 660,
#  ('100% pure pumpkin',): 660,
#  ('93% ground beef',): 660,
#  ('thin & light tortilla chips',): 662,
#  ('cream cheese',): 664,
#  ('flaky biscuits',): 665,
#  ('organic beef broth',): 666,
#  ('organic white cheddar popcorn',): 666,
#  ('boneless skinless chicken breast fillets',): 667,
#  ('organic free range low sodium chicken broth',): 668,
#  ('white giant paper towel rolls',): 668,
#  ('mini seedless cucumbers',): 669,
#  ('beef franks',): 669,
#  ('arancita rossa',): 669,
#  ('margherita pizza',): 670,
#  ('kidz all natural baked chicken nuggets',): 670,
#  ('original rotisserie chicken',): 671,
#  ('grape tomatoes',): 672,
#  ('dha omega 3 vitamin d milk',): 672,
#  ('curate melon pomelo sparking water',): 672,
#  ('red plums',): 673,
#  ('lactose free 2% reduced fat milk',): 673,
#  ('ultra soft facial tissues',): 673,
#  ('traditional plain greek yogurt',): 673,
#  ('organic baby bella mushrooms',): 676,
#  ('seven grain crispy tenders',): 678,
#  ('authentic french brioche',): 678,
#  ('original black box tablewater cracker',): 678,
#  ('lowfat small curd cottage cheese',): 680,
#  ('strawberry on the bottom nonfat greek yogurt',): 680,
#  ('yobaby blueberry apple yogurt',): 681,
#  ('presliced everything bagels',): 682,
#  ('organic purple kale',): 682,
#  ('diet coke',): 683,
#  ('saltine crackers',): 683,
#  ('organic mango chunks',): 685,
#  ('tommy/kent/keitt/haden mango',): 686,
#  ('organic cannellini beans',): 686,
#  ('organic green onions',): 688,
#  ('whole grain cheddar baked snack crackers',): 688,
#  ('cherrios honey nut',): 689,
#  ('organic sliced crimini mushrooms',): 691,
#  ('sonoma traditional flour tortillas 10 count',): 692,
#  ('organic shredded mild cheddar',): 692,
#  ('ranch dressing',): 692,
#  ('basil',): 692,
#  ('premium pure cane granulated sugar',): 693,
#  ('peach on the bottom nonfat greek yogurt',): 696,
#  ('butter',): 697,
#  ('fancy eggplant',): 697,
#  ('grade a large brown eggs',): 698,
#  ('natural classic pork breakfast sausage',): 698,
#  ('uncured black forest ham',): 698,
#  ('original real vegetable chips',): 700,
#  ('organic lite coconut milk',): 700,
#  ('naturals savory turkey breakfast sausage',): 700,
#  ('large grade aa eggs',): 700,
#  ('sweet potato yam',): 700,
#  ('pink lady (cripps) apple',): 701,
#  ('cheerios cereal',): 702,
#  ('select-a-size white paper towels',): 702,
#  ('organic edamame',): 702,
#  ('organic red potatoes',): 703,
#  ('organic cottage cheese',): 703,
#  ('organic short grain brown rice',): 704,
#  ('oats & honey gluten free granola',): 704,
#  ('light semisoft cheese',): 706,
#  ('mediterranean mint gelato',): 706,
#  ('100% natural spring water',): 706,
#  ('organic green beans',): 707,
#  ('everything bagels',): 709,
#  ('lowfat vanilla yogurt',): 709,
#  ('uncured pepperoni',): 710,
#  ('unsweetened coconut milk beverage',): 711,
#  ('100% lactose free fat free milk',): 711,
#  ('celery',): 711,
#  ('organic lactose free whole milk',): 713,
#  ('zbar organic chocolate brownie energy snack',): 713,
#  ('natural free & clear dish liquid',): 713,
#  ('broccoli florettes',): 713,
#  ('organic blueberry waffles',): 714,
#  ('wild berry smoothie',): 715,
#  ('crunchy almond butter',): 715,
#  ('root beer',): 716,
#  ('frozen organic blueberries',): 716,
#  ('organic fuji apples',): 717,
#  ('juice beverage cold pressed kale apple ginger romaine spinach cucumber celery parsley lemon',): 718,
#  ('baby seedless cucumbers',): 719,
#  ('backyard barbeque potato chips',): 719,
#  ('grilled chicken breast strips',): 720,
#  ('crescent rolls',): 721,
#  ('organic  whole milk',): 722,
#  ('spaghetti  no 12',): 723,
#  ('organic kale greens',): 724,
#  ('organic homestyle waffles',): 725,
#  ('shells & real aged cheddar macaroni & cheese',): 725,
#  ('apple cinnamon gogo squeez',): 726,
#  ('cold brew coffee',): 726,
#  ('jalapeno hummus',): 726,
#  ('philadelphia original cream cheese',): 727,
#  ('organic beans & rice cheddar cheese burrito',): 727,
#  ('sweet onions',): 729,
#  ('all natural marinara sauce',): 730,
#  ('organic wheat-free & gluten-free original crackers',): 731,
#  ('apple juice',): 732,
#  ('vanilla almond breeze',): 732,
#  ('1% low fat milk',): 732,
#  ('sauvignon blanc',): 733,
#  ('broccoli & cheddar bake meal bowl',): 733,
#  ('raisins',): 733,
#  ('organic red lentils',): 734,
#  ('plain pre-sliced bagels',): 735,
#  ('yobaby peach pear yogurt',): 737,
#  ('organic hot house tomato',): 738,
#  ('emmentaler swiss slices',): 740,
#  ('honey greek yogurt',): 740,
#  ('white cheddar popcorn',): 740,
#  ('organic boneless skinless chicken breast',): 741,
#  ('organic braeburn apple',): 741,
#  ('scoops! tortilla chips',): 741,
#  ('organic stringles mozzarella string cheese',): 744,
#  ('cucumber & garlic  tzatziki',): 744,
#  ('organic large grade aa omega-3 eggs',): 744,
#  ('no pulp calcium & vitamin d pure premium 100% pure orange juice',): 746,
#  ('plain mini bagels',): 747,
#  ('corn chips',): 748,
#  ('veggie chips',): 749,
#  ('organic chicken bone broth',): 749,
#  ('air chilled breaded chicken breast nuggets',): 751,
#  ('baby food stage 2 blueberry pear & purple carrot',): 751,
#  ('mini cucumbers',): 753,
#  ('milk vitamin d',): 754,
#  ('organic unbleached all-purpose flour',): 754,
#  ('goldfish cheddar baked snack crackers',): 756,
#  ('whole organic omega 3 milk',): 759,
#  ('dark chocolate pretzels with sea salt',): 759,
#  ('chicken breast tenders breaded',): 760,
#  ('french vanilla creamer',): 761,
#  ('yellow grape tomatoes',): 761,
#  ('organic mango',): 763,
#  ('pure baking soda',): 764,
#  ('natural sharp cheddar sliced cheese',): 765,
#  ('organic nectarine',): 766,
#  ('celery sticks',): 766,
#  ('penne pasta',): 766,
#  ('bunny pasta with yummy cheese macaroni & cheese',): 767,
#  ('provolone',): 771,
#  ('cane sugar',): 776,
#  ('gluten free 7 grain bread',): 777,
#  ('organic cinnamon crunch cereal',): 777,
#  ('shredded sharp cheddar cheese',): 778,
#  ('cauliflower florets',): 779,
#  ('roasted & salted almonds',): 779,
#  ('garlic hummus',): 779,
#  ('organic sliced white mushrooms',): 780,
#  ('zero calorie cola',): 782,
#  ('cheese pizza snacks',): 783,
#  ('organic mayonnaise',): 783,
#  ('traditional hummus',): 783,
#  ('vanilla skyr style yogurt',): 784,
#  ('organic long grain white rice',): 785,
#  ('grated parmesan cheese',): 787,
#  ('fat free skim milk',): 788,
#  ("crunchy oats 'n honey granola bars",): 792,
#  ('low fat 1% milk',): 794,
#  ('gold potato',): 795,
#  ('raspberry yoghurt',): 796,
#  ('organic lemonade',): 798,
#  ('organic beef uncured hot dogs',): 798,
#  ('organic lightly salted brown rice cakes',): 799,
#  ('red mango',): 799,
#  ('squeeze tomato ketchup',): 803,
#  ('organic red grapes',): 804,
#  ('bicolor sweet corn',): 805,
#  ('organic fresh basil',): 806,
#  ('organic bagged carrots',): 806,
#  ('organic orange juice',): 808,
#  ('whole strawberries',): 810,
#  ('chopped spinach',): 811,
#  ('original rice pilaf mix',): 812,
#  ('chocolate chip cookie dough ice cream',): 813,
#  ('almond nut & rice cracker snacks',): 815,
#  ('organic low fat milk',): 817,
#  ('parsley italian (flat) new england grown',): 818,
#  ('passionfruit sparkling water',): 818,
#  ('synergy organic kombucha gingerberry',): 818,
#  ('unrefined virgin coconut oil',): 823,
#  ('organic original almond milk',): 824,
#  ('super soft taco flour tortillas',): 826,
#  ('organic vanilla extract',): 826,
#  ('organic distilled white vinegar',): 829,
#  ('gluten free dark chocolate chunk chewy with a crunch granola bars',): 831,
#  ('pesto tortellini  bowls',): 831,
#  ('organic extra large brown eggs',): 832,
#  ('garlic & fine herbs gournay cheese',): 832,
#  ('original popcorn',): 833,
#  ('citrus mandarins organic',): 834,
#  ('extra fancy unsalted mixed nuts',): 834,
#  ('canola oil',): 834,
#  ('fat free strawberry yogurt',): 834,
#  ('non fat acai & mixed berries yogurt',): 835,
#  ('panko bread crumbs',): 836,
#  ('sliced white mushrooms',): 839,
#  ('organic raw unfiltered apple cider vinegar',): 842,
#  ('organic quick oats',): 845,
#  ('dairy free unsweetened coconut milk',): 845,
#  ('roasted turkey',): 846,
#  ('taco seasoning',): 849,
#  ('no pulp calcium & vitamin d pure orange juice',): 849,
#  ('organic sliced peaches',): 851,
#  ('organic sea salt roasted seaweed snacks',): 852,
#  ('gluten free chocolate chip cookies',): 853,
#  ('pulp free orange juice',): 854,
#  ('penne rigate',): 855,
#  ('vitamin d whole milk',): 856,
#  ('spaghetti pasta',): 856,
#  ('serrano chile peppers',): 857,
#  ('coconut water',): 858,
#  ('organic golden delicious apple',): 858,
#  ('nonfat icelandic style strawberry yogurt',): 860,
#  ('black plum',): 861,
#  ('honey yoghurt',): 861,
#  ('honeydew melon',): 868,
#  ('organic frozen mango chunks',): 869,
#  ('sweet potatoes',): 869,
#  ('organic no salt added diced tomatoes',): 871,
#  ('organic red chard greens',): 871,
#  ('macaroni shells & white cheddar cheese',): 875,
#  ('dha omega 3 reduced fat 2% milk',): 876,
#  ('organic simply naked pita chips',): 876,
#  ('organic greek whole milk blended vanilla bean yogurt',): 877,
#  ('authentic french brioche hamburger buns',): 878,
#  ('organic red potato',): 878,
#  ('firm tofu',): 878,
#  ('organic whipping cream',): 881,
#  ('lemon yogurt',): 882,
#  ('large greenhouse tomato',): 882,
#  ('whole milk ricotta cheese',): 888,
#  ('cauliflower',): 888,
#  ('organic mixed vegetables',): 890,
#  ('organic cream cheese bar',): 891,
#  ('bunny-luv fresh organic carrots',): 892,
#  ('collard greens',): 892,
#  ('walnut halves & pieces',): 895,
#  ('eggo homestyle waffles',): 895,
#  ('lemon sparkling water',): 897,
#  ('mozzarella string cheese',): 899,
#  ('mild cheddar cheese sticks',): 901,
#  ('curate cherry lime sparkling water',): 902,
#  ('apples',): 902,
#  ('organic yellow squash',): 903,
#  ('smoked turkey breast slices',): 907,
#  ('red leaf lettuce',): 913,
#  ('large brown eggs',): 917,
#  ('apple cider vinegar',): 917,
#  ('cheddar bunnies snack crackers',): 921,
#  ('fresh ca grown eggs',): 922,
#  ('aged white cheddar baked rice & corn puffs gluten free lunch packs',): 924,
#  ('organic rosemary',): 925,
#  ('organic low sodium vegetable broth',): 925,
#  ('kiwi sandia sparkling water',): 926,
#  ('organic macaroni shells & real aged cheddar',): 928,
#  ('organic vanilla almond milk',): 931,
#  ('organic medjool dates',): 931,
#  ('total 0% with honey nonfat greek strained yogurt',): 936,
#  ('aluminum foil',): 938,
#  ('organic english cucumber',): 938,
#  ('reduced fat milk',): 940,
#  ('kiwi',): 940,
#  ('organic pinto beans',): 941,
#  ('organic dijon mustard',): 944,
#  ('chopped walnuts',): 944,
#  ('organic romaine leaf',): 945,
#  ('organic whole wheat bread',): 945,
#  ('organic red on the vine tomato',): 945,
#  ('raspberry preserves',): 945,
#  ('organic multigrain waffles',): 945,
#  ('orange calcium & vitamin d pulp free',): 946,
#  ('sliced black olives',): 946,
#  ('butternut squash',): 947,
#  ('cage free large white eggs',): 947,
#  ('organic small curd cottage cheese',): 953,
#  ('organic honey sweet whole wheat bread',): 955,
#  ('plain bagels',): 956,
#  ('almondbreeze unsweetened',): 956,
#  ('organic italian salad',): 966,
#  ('fresh mozzarella ball',): 969,
#  ('natural artisan water',): 970,
#  ('vitamin d organic whole milk',): 972,
#  ('boneless skinless chicken thighs',): 972,
#  ('mixed fruit fruit snacks',): 977,
#  ('organic baby kale mix',): 978,
#  ('bing cherries',): 979,
#  ('dried mango',): 980,
#  ('organic dark chocolate peanut butter cups',): 980,
#  ('grade a large eggs cage free omega 3',): 981,
#  ('thin crust pepperoni pizza',): 985,
#  ('cran raspberry sparkling water',): 987,
#  ('smartwater',): 987,
#  ('lime',): 991,
#  ('alpine spring water',): 992,
#  ('naturals chicken nuggets',): 992,
#  ('organic orange bell pepper',): 994,
#  ('red seedless grapes',): 995,
#  ('boomchickapop sea salt popcorn',): 998,
#  ('medium cheddar cheese block',): 998,
#  ('organic strawberry fruit spread',): 999,
#  ('organic chicken strips',): 1002,
#  ('potato yukon gold organic',): 1003,
#  ('almond breeze original almond milk',): 1005,
#  ('reduced fat milk 100% lactose free',): 1006,
#  ('real mayonnaise',): 1007,
#  ('organic chicken stock',): 1009,
#  ('organic chicken broth',): 1009,
#  ('baby arugula',): 1012,
#  ('coke classic',): 1014,
#  ('organic strawberry smoothie',): 1015,
#  ('organic milk reduced fat 2% milkfat',): 1016,
#  ('mint',): 1016,
#  ('kids organic chocolate chip zbars',): 1020,
#  ('natural premium coconut water',): 1021,
#  ('blueberry yoghurt',): 1024,
#  ('organic chopped spinach',): 1024,
#  ('strawberry rhubarb yoghurt',): 1025,
#  ('yokids blueberry & strawberry/vanilla yogurt',): 1026,
#  ('green peas',): 1027,
#  ('organic 1% low fat milk',): 1027,
#  ('organic vegetable broth',): 1030,
#  ('vanilla pure almond milk',): 1030,
#  ('organic apple juice',): 1031,
#  ('salted tub of butter',): 1035,
#  ('whole wheat bread',): 1038,
#  ('oven roasted turkey',): 1040,
#  ('organic butterhead (boston butter bibb) lettuce',): 1041,
#  ('organic spaghetti squash',): 1042,
#  ('colby cheese sticks',): 1044,
#  ('yogurt strained low-fat coconut',): 1044,
#  ('pure & natural sour cream',): 1045,
#  ('organic good seed bread',): 1047,
#  ('original semisoft cheese',): 1047,
#  ('cinnamon rolls with icing',): 1048,
#  ('vanilla unsweetened almond milk',): 1050,
#  ('organic original hommus',): 1050,
#  ('total 0% raspberry yogurt',): 1050,
#  ('red potatoes',): 1057,
#  ('marinara pasta sauce',): 1059,
#  ('0% greek strained yogurt',): 1059,
#  ('whole almonds',): 1060,
#  ('crackers cheddar bunnies snack packs',): 1060,
#  ('cream cheese spread',): 1062,
#  ('large yellow flesh nectarine',): 1062,
#  ('organic plain greek whole milk yogurt',): 1068,
#  ('mandarin oranges',): 1068,
#  ('dressing jersey sweet onion calorie free',): 1070,
#  ('organic uncured sliced black forest ham',): 1071,
#  ('seedless small watermelon',): 1073,
#  ('original whipped cream cheese',): 1076,
#  ('vanilla ice cream',): 1076,
#  ('crushed tomatoes',): 1076,
#  ('purified water',): 1079,
#  ('organic summer strawberry bunny fruit snacks',): 1080,
#  ('hint of sea salt almond nut thins',): 1082,
#  ('organic spinach bunch',): 1083,
#  ('organic beef hot dogs',): 1088,
#  ('organic roasted sliced chicken breast',): 1091,
#  ('i heart baby kale',): 1093,
#  ('cola',): 1094,
#  ('organic cauliflower',): 1098,
#  ('blackberry cucumber sparkling water',): 1099,
#  ('blood oranges',): 1101,
#  ('rainbow bell peppers',): 1101,
#  ('tomato paste',): 1103,
#  ('organic thompson seedless raisins',): 1103,
#  ('organic whole grain wheat english muffins',): 1105,
#  ('organic whole cashews',): 1107,
#  ('green tea with ginseng and honey',): 1107,
#  ('almonds & sea salt in dark chocolate',): 1110,
#  ('roasted pine nut hummus',): 1113,
#  ('organic sunday bacon',): 1113,
#  ('organic chicken & apple sausage',): 1125,
#  ('sea salt potato chips',): 1128,
#  ('romaine lettuce',): 1129,
#  ('organic 21 grain thin sliced bread',): 1131,
#  ('trail mix',): 1138,
#  ('organic bunny fruit snacks berry patch',): 1141,
#  ('organic plain whole milk yogurt',): 1144,
#  ('original hot sauce',): 1145,
#  ('organic whole milk with dha omega-3',): 1149,
#  ('organic blue corn tortilla chips',): 1151,
#  ('1% lowfat milk',): 1153,
#  ('organic free range chicken broth',): 1154,
#  ('sweet kale salad mix',): 1154,
#  ('100 calorie  per bag popcorn',): 1162,
#  ('italian extra virgin olive oil',): 1165,
#  ('tomato sauce',): 1172,
#  ('organic whipped naturally buttery spread',): 1172,
#  ('cereal',): 1189,
#  ('gluten free whole grain bread',): 1199,
#  ('organic lowfat 1% milk',): 1210,
#  ('85% lean ground beef',): 1215,
#  ('goat cheese crumbles',): 1217,
#  ('light brown sugar',): 1218,
#  ('uncured slow cooked ham',): 1218,
#  ('organic red delicious apple',): 1222,
#  ('mild salsa',): 1224,
#  ('green seedless grapes',): 1230,
#  ('organic riced cauliflower',): 1232,
#  ('plain greek yogurt',): 1236,
#  ('grade a large white eggs',): 1237,
#  ('tomato ketchup',): 1240,
#  ('tilapia filet',): 1242,
#  ('organic green leaf lettuce',): 1243,
#  ('organic romaine hearts',): 1246,
#  ('2% reduced fat dha omega-3 reduced fat milk',): 1246,
#  ('ginger ale',): 1247,
#  ('baked aged white cheddar rice and corn puffs',): 1252,
#  ('natural chicken & sage breakfast sausage',): 1255,
#  ('toasted coconut almondmilk blend',): 1256,
#  ('kale greens',): 1256,
#  ('organic extra virgin olive oil',): 1258,
#  ('organic whole kernel sweet corn no salt added',): 1261,
#  ('organic extra large grade aa brown eggs',): 1261,
#  ('total 2% all natural low fat 2% milkfat greek strained yogurt',): 1262,
#  ('organic whole grassmilk milk',): 1263,
#  ('natural artesian water',): 1269,
#  ('organic tomato sauce',): 1269,
#  ('organic cheese frozen pizza',): 1276,
#  ('packaged grape tomatoes',): 1281,
#  ('sparkling water',): 1282,
#  ('skim milk',): 1284,
#  ('medium navel orange',): 1285,
#  ('chocolate ice cream',): 1285,
#  ('organic iceberg lettuce',): 1287,
#  ('flat parsley bunch',): 1308,
#  ('pita chips simply naked',): 1309,
#  ('classic hummus',): 1311,
#  ('organic tortilla chips',): 1314,
#  ('chocolate chip cookies',): 1315,
#  ('whole milk plain yogurt',): 1316,
#  ('corn tortillas',): 1317,
#  ('organic brown rice',): 1324,
#  ('baby cucumbers',): 1326,
#  ('celery hearts',): 1329,
#  ('mini original babybel cheese',): 1332,
#  ('original pure creamy almond milk',): 1332,
#  ('water',): 1333,
#  ('organic bunch beets',): 1333,
#  ('sea salt & vinegar potato chips',): 1334,
#  ('organic large brown eggs',): 1335,
#  ('cage free brown eggs-large grade a',): 1338,
#  ('organic red cabbage',): 1338,
#  ('honeycrisp apples',): 1343,
#  ('sinfully sweet campari tomatoes',): 1343,
#  ('diced tomatoes',): 1349,
#  ('organic ketchup',): 1351,
#  ('organic salted butter',): 1355,
#  ('sugar snap peas',): 1356,
#  ('organic unsweetened vanilla almond milk',): 1364,
#  ('raisin bran cereal',): 1366,
#  ('iceberg lettuce',): 1367,
#  ('strawberry preserves',): 1371,
#  ('organic turkey bacon',): 1376,
#  ('seedless cucumbers',): 1385,
#  ('orange sparkling water',): 1386,
#  ('berry medley',): 1388,
#  ('organic cripps pink apples',): 1388,
#  ('grapefruit sparkling water',): 1396,
#  ('lemon hummus',): 1397,
#  ('super greens salad',): 1403,
#  ('orange juice',): 1403,
#  ('organic rainbow carrots',): 1406,
#  ('black beans',): 1410,
#  ('total 0% nonfat plain greek yogurt',): 1410,
#  ('english seedless cucumber',): 1415,
#  ('xl emerald white seedless grapes',): 1417,
#  ('spaghetti',): 1421,
#  ('non fat raspberry yogurt',): 1421,
#  ('total 2% lowfat plain greek yogurt',): 1422,
#  ('organic appleapple',): 1430,
#  ('organic dill',): 1430,
#  ('trilogy kombucha drink',): 1432,
#  ('original nooks & crannies english muffins',): 1434,
#  ('air chilled organic boneless skinless chicken breasts',): 1436,
#  ('asparation/broccolini/baby broccoli',): 1437,
#  ('organic low sodium chicken broth',): 1438,
#  ('white corn',): 1441,
#  ('vine ripe tomatoes',): 1452,
#  ('basil pesto',): 1453,
#  ('total 2% all natural plain greek yogurt',): 1454,
#  ('organic medium salsa',): 1457,
#  ('frozen broccoli florets',): 1465,
#  ('super spinach! baby spinach baby bok choy sweet baby kale',): 1472,
#  ('organic large grade a brown eggs',): 1482,
#  ('chicken & maple breakfast sausage',): 1494,
#  ('fridge pack cola',): 1495,
#  ('sourdough bread',): 1496,
#  ('organic shredded mozzarella',): 1509,
#  ('globe eggplant',): 1510,
#  ('original veggie straws',): 1513,
#  ('organic baby kale',): 1516,
#  ('guacamole',): 1525,
#  ('total 2% greek strained yogurt with cherry 5.3 oz',): 1536,
#  ('sea salt pita chips',): 1537,
#  ('organic tomato paste',): 1545,
#  ('2% reduced fat organic milk',): 1551,
#  ('organic mexican blend finely shredded cheese',): 1551,
#  ('pretzel crisps original deli style pretzel crackers',): 1553,
#  ('organic american cheese singles',): 1566,
#  ('sparkling mineral water',): 1571,
#  ('european cucumber',): 1577,
#  ('distilled water',): 1591,
#  ('ezekiel 4:9 bread organic sprouted whole grain',): 1593,
#  ('sparkling water berry',): 1600,
#  ('macaroni & cheese',): 1600,
#  ('organic grade a large brown eggs',): 1608,
#  ('milk organic vitamin d',): 1616,
#  ('organic tomato basil pasta sauce',): 1619,
#  ('organic baby spinach salad',): 1620,
#  ('organic snipped green beans',): 1620,
#  ('organic creamy peanut butter',): 1622,
#  ('pure coconut water',): 1631,
#  ('organic thyme',): 1632,
#  ('reduced fat 2% milk',): 1640,
#  ('shallot',): 1644,
#  ('roasted red pepper hummus',): 1644,
#  ('organic butternut squash',): 1652,
#  ('organic green seedless grapes',): 1654,
#  ('mango chunks',): 1659,
#  ('total 2% lowfat greek strained yogurt with blueberry',): 1663,
#  ('total 2% lowfat greek strained yogurt with peach',): 1670,
#  ('icelandic style skyr blueberry non-fat yogurt',): 1670,
#  ('organic mint',): 1676,
#  ('vanilla skyr nonfat yogurt',): 1688,
#  ('yokids squeezers organic low-fat yogurt strawberry',): 1690,
#  ('white onion',): 1690,
#  ('sustainably soft bath tissue',): 1695,
#  ('organic large green asparagus',): 1695,
#  ('organic broccoli crowns',): 1700,
#  ('organic yams',): 1703,
#  ('salted butter',): 1715,
#  ('spinach',): 1716,
#  ('organic old fashioned rolled oats',): 1727,
#  ('marinara sauce',): 1727,
#  ('unsalted pure irish butter',): 1729,
#  ('organic yellow peaches',): 1746,
#  ('organic frozen peas',): 1754,
#  ('organic leek',): 1754,
#  ('organic unsalted butter',): 1761,
#  ('original no pulp 100% florida orange juice',): 1803,
#  ('lemonade',): 1805,
#  ('roasted turkey breast',): 1805,
#  ('organic egg whites',): 1825,
#  ('organic bosc pear',): 1827,
#  ('organic jalapeno pepper',): 1828,
#  ('organic shredded carrots',): 1848,
#  ('organic spring mix salad',): 1853,
#  ('sweet onion',): 1872,
#  ('uncured hickory smoked sunday bacon',): 1884,
#  ('electrolyte enhanced water',): 1889,
#  ('organic green cabbage',): 1891,
#  ('organic baby rainbow carrots',): 1904,
#  ('creamy almond butter',): 1912,
#  ('large grapefruit',): 1913,
#  ('heavy whipping cream',): 1917,
#  ('organic raw kombucha gingerade',): 1918,
#  ('natural spring water',): 1924,
#  ('oven roasted turkey breast',): 1935,
#  ('organic diced tomatoes',): 1950,
#  ('total 2% all natural greek strained yogurt with honey',): 1969,
#  ('peach pear flavored sparkling water',): 1970,
#  ('creamy peanut butter',): 1991,
#  ('shredded mozzarella',): 2024,
#  ('boneless skinless chicken breast',): 2049,
#  ('organic white onions',): 2064,
#  ('watermelon chunks',): 2073,
#  ('organic 2% reduced fat milk',): 2082,
#  ('organic heavy whipping cream',): 2085,
#  ('sour cream',): 2085,
#  ('organic bread with 21 whole grains',): 2101,
#  ('organic bell pepper',): 2138,
#  ('cherubs heavenly salad tomatoes',): 2141,
#  ('organic hothouse cucumbers',): 2156,
#  ('lightly salted baked snap pea crisps',): 2175,
#  ('organic fat free milk',): 2176,
#  ('blackberries',): 2176,
#  ('total greek strained yogurt',): 2211,
#  ('gala apples',): 2226,
#  ('organic celery hearts',): 2256,
#  ('organic milk',): 2264,
#  ('original orange juice',): 2270,
#  ('ground turkey breast',): 2277,
#  ('pineapple chunks',): 2279,
#  ('brussels sprouts',): 2294,
#  ('baby spinach',): 2296,
#  ('romaine hearts',): 2300,
#  ('total 0% nonfat greek yogurt',): 2348,
#  ('total 0% greek yogurt',): 2351,
#  ('organic large grade aa brown eggs',): 2353,
#  ('organic romaine',): 2354,
#  ('shredded mild cheddar cheese',): 2366,
#  ('organic red radish bunch',): 2387,
#  ('organic coconut milk',): 2397,
#  ('yellow bell pepper',): 2416,
#  ('cantaloupe',): 2416,
#  ('organic sour cream',): 2428,
#  ('total 2% with strawberry lowfat greek strained yogurt',): 2461,
#  ('organic roasted turkey breast',): 2468,
#  ('hass avocado',): 2472,
#  ('fresh ginger root',): 2493,
#  ('100% recycled paper towels',): 2535,
#  ('organic basil',): 2554,
#  ('unsweetened vanilla almond milk',): 2558,
#  ('honey nut cheerios',): 2558,
#  ('frozen organic wild blueberries',): 2559,
#  ('pure sparkling water',): 2579,
#  ('whipped cream cheese',): 2601,
#  ('no salt added black beans',): 2620,
#  ('organic roma tomato',): 2629,
#  ('fat free milk',): 2635,
#  ('green beans',): 2641,
#  ('italian sparkling mineral water',): 2655,
#  ('sharp cheddar cheese',): 2657,
#  ('organic garbanzo beans',): 2658,
#  ('organic extra firm tofu',): 2699,
#  ('organic large brown grade aa cage free eggs',): 2738,
#  ('green onions',): 2739,
#  ('organic whole strawberries',): 2773,
#  ('red raspberries',): 2784,
#  ('organic russet potato',): 2816,
#  ('vanilla almond breeze almond milk',): 2825,
#  ('clementines',): 2860,
#  ('organic romaine lettuce',): 2898,
#  ('russet potato',): 2921,
#  ('organic bartlett pear',): 2933,
#  ('organic baby broccoli',): 2960,
#  ('organic spring mix',): 2984,
#  ('organic broccoli florets',): 3002,
#  ('organic sticks low moisture part skim mozzarella string cheese',): 3014,
#  ('sparkling lemon water',): 3044,
#  ('organic reduced fat milk',): 3053,
#  ('bartlett pears',): 3102,
#  ('feta cheese crumbles',): 3109,
#  ('whole milk',): 3120,
#  ('shredded parmesan',): 3139,
#  ('pure irish butter',): 3163,
#  ('unsweetened original almond breeze almond milk',): 3187,
#  ('granny smith apples',): 3202,
#  ('100% raw coconut water',): 3252,
#  ('unsalted butter',): 3268,
#  ('organic banana',): 3284,
#  ('soda',): 3294,
#  ('2% reduced fat milk',): 3408,
#  ('grape white/green seedless',): 3450,
#  ('clementines bag',): 3463,
#  ('banana', 'clementines bag'): 502,
#  ('organic black beans',): 3466,
#  ('organic carrot bunch',): 3509,
#  ('organic broccoli',): 3602,
#  ('bag of organic bananas', 'organic broccoli'): 562,
#  ('red onion',): 3682,
#  ('garlic',): 3748,
#  ('organic grade a free range large brown eggs',): 3755,
#  ('orange bell pepper',): 3776,
#  ('banana', 'orange bell pepper'): 506,
#  ('organic reduced fat 2% milk',): 3871,
#  ('organic lacinato (dinosaur) kale',): 3875,
#  ('uncured genoa salami',): 3888,
#  ('large alfresco eggs',): 3932,
#  ('grated parmesan',): 3951,
#  ('sparkling natural mineral water',): 3962,
#  ('roma tomato',): 3969,
#  ('banana', 'roma tomato'): 606,
#  ('jalapeno peppers',): 4104,
#  ('jalapeno peppers', 'limes'): 584,
#  ('bunched cilantro',): 4210,
#  ('bunched cilantro', 'limes'): 592,
#  ('organic navel orange',): 4227,
#  ('bag of organic bananas', 'organic navel orange'): 757,
#  ('lime sparkling water',): 4232,
#  ('lime sparkling water', 'sparkling water grapefruit'): 535,
#  ("organic d'anjou pears", 'organic strawberries'): 502,
#  ('bag of organic bananas', "organic d'anjou pears"): 644,
#  ('organic kiwi', 'organic strawberries'): 561,
#  ('bag of organic bananas', 'organic kiwi'): 694,
#  ('extra virgin olive oil',): 4557,
#  ('organic baby spinach', 'organic ginger root'): 503,
#  ('bag of organic bananas', 'organic ginger root'): 525,
#  ('unsweetened almondmilk',): 4672,
#  ('boneless skinless chicken breasts',): 4683,
#  ('banana', 'boneless skinless chicken breasts'): 626,
#  ('hass avocados',): 4764,
#  ('bag of organic bananas', 'hass avocados'): 586,
#  ('banana', 'organic whole string cheese'): 517,
#  ('organic strawberries', 'organic whole string cheese'): 539,
#  ('bag of organic bananas', 'organic whole string cheese'): 627,
#  ('red vine tomato',): 5024,
#  ('banana', 'red vine tomato'): 631,
#  ('spring water',): 5071,
#  ('broccoli crown', 'organic avocado'): 503,
#  ('broccoli crown', 'organic baby spinach'): 541,
#  ('broccoli crown', 'large lemon'): 543,
#  ('banana', 'broccoli crown'): 967,
#  ('banana', 'organic garnet sweet potato (yam)'): 586,
#  ('organic baby spinach', 'organic garnet sweet potato (yam)'): 648,
#  ('bag of organic bananas', 'organic garnet sweet potato (yam)'): 666,
#  ('bag of organic bananas', 'organic peeled whole baby carrots'): 608,
#  ('banana', 'organic peeled whole baby carrots'): 673,
#  ('organic unsweetened almond milk',): 5186,
#  ('bag of organic bananas', 'organic unsweetened almond milk'): 643,
#  ('blueberries',): 5190,
#  ('banana', 'blueberries'): 755,
#  ('organic granny smith apple', 'organic strawberries'): 526,
#  ('bag of organic bananas', 'organic granny smith apple'): 688,
#  ('organic red bell pepper', 'organic strawberries'): 590,
#  ('bag of organic bananas', 'organic red bell pepper'): 660,
#  ('100% whole wheat bread',): 5358,
#  ('100% whole wheat bread', 'banana'): 667,
#  ('green bell pepper', 'red peppers'): 502,
#  ('banana', 'green bell pepper'): 640,
#  ('bag of organic bananas', 'organic italian parsley bunch'): 500,
#  ('organic garlic', 'organic italian parsley bunch'): 522,
#  ('organic strawberries', 'small hass avocado'): 521,
#  ('bag of organic bananas', 'small hass avocado'): 532,
#  ('banana', 'small hass avocado'): 901,
#  ('red peppers',): 5659,
#  ('banana', 'red peppers'): 864,
#  ('organic strawberries', 'organic tomato cluster'): 504,
#  ('organic hass avocado', 'organic tomato cluster'): 521,
#  ('bag of organic bananas', 'organic tomato cluster'): 670,
#  ('half & half',): 5868,
#  ('banana', 'half & half'): 549,
#  ('organic baby spinach', 'organic small bunch celery'): 536,
#  ...}

# %%
# save patterns to a dataframe and create column names
patterns_df = pd.DataFrame(patterns_all.items(), columns=['product_name', 'support_level'])

# %%
# take out brackets and commas from the product_name column
patterns_df['product_name'] = patterns_df['product_name'].astype(str).str.replace(r'\(|\)|,', '')
# Out:
# <ipython-input-68-95dd36bdd161>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   patterns_df['product_name'] = patterns_df['product_name'].astype(str).str.replace(r'\(|\)|,', '')

# %%
# patterns_df = patterns_df.strip("\''", "")

# %%
# save patterns to a .csv file in a data folder
patterns_df.to_csv('data/patterns.csv', index = False)

# %%
# Identify itemsets with minimum confidence level
rules = pyfpgrowth.generate_association_rules(patterns_all, 0.1)

# %%
rules
# Out:
# {('clementines bag',): (('banana',), 0.144961016459717),
#  ('organic broccoli',): (('bag of organic bananas',), 0.15602443087173792),
#  ('orange bell pepper',): (('banana',), 0.1340042372881356),
#  ('roma tomato',): (('banana',), 0.15268329554043839),
#  ('jalapeno peppers',): (('limes',), 0.14230019493177387),
#  ('bunched cilantro',): (('limes',), 0.14061757719714965),
#  ('organic navel orange',): (('bag of organic bananas',), 0.17908682280577243),
#  ('lime sparkling water',): (('sparkling water grapefruit',),
#   0.1264177693761815),
#  ('boneless skinless chicken breasts',): (('banana',), 0.13367499466154176),
#  ('hass avocados',): (('bag of organic bananas',), 0.12300587741393787),
#  ('red vine tomato',): (('banana',), 0.12559713375796178),
#  ('organic unsweetened almond milk',): (('bag of organic bananas',),
#   0.12398765908214424),
#  ('blueberries',): (('banana',), 0.14547206165703275),
#  ('100% whole wheat bread',): (('banana',), 0.12448674878686077),
#  ('red peppers',): (('banana',), 0.1526771514401838),
#  ('cucumber kirby',): (('banana',), 0.11240048576440427),
#  ('organic fuji apple',): (('banana',), 0.16619500900437356),
#  ('bag of organic bananas',
#   'organic hass avocado'): (('organic strawberries',), 0.27663696241766755),
#  ('bag of organic bananas', 'organic raspberries'): (('organic strawberries',),
#   0.3437334743521946),
#  ('organic hass avocado', 'organic raspberries'): (('bag of organic bananas',),
#   0.49353049907578556),
#  ('bag of organic bananas',
#   'organic strawberries'): (('organic baby spinach',), 0.18195908245505268),
#  ('organic raspberries', 'organic strawberries'): (('bag of organic bananas',),
#   0.37037037037037035),
#  ('organic hass avocado',
#   'organic strawberries'): (('bag of organic bananas',), 0.4343065693430657),
#  ('bag of organic bananas',
#   'organic baby spinach'): (('organic strawberries',), 0.2495748299319728),
#  ('organic baby spinach',
#   'organic strawberries'): (('bag of organic bananas',), 0.3395026026604974)}

# %%
# Create a dataframe of frequent patterns and transpose the dataframe
df_rules = pd.DataFrame(rules).T

# %%
# sort a dataframe in descending orders
df_rules_sorted = df_rules.sort_values(ascending = False, by = 1)

# %%
# reset index to display pair products
df_rules_sorted.reset_index(level = 0, inplace = True)
df_rules_sorted.reset_index(level = 0, inplace = True)

# %%
# rename columns to antecedent, consequent, and calculated confidence level
df_rules_sorted.rename(columns = {'index': 'consequent_2', 'level_0':'consequent_1', 0:'antecedent', 1: 'confidence_level'}, inplace = True)

# %%
# take out brackets and commas in the consequent column
df_rules_sorted['antecedent'] = df_rules_sorted['antecedent'].astype(str).str.replace(r'\(|\)|,', '')
# reorder columns
cols = ['antecedent', 'consequent_1', 'consequent_2', 'confidence_level']
df_rules_sorted = df_rules_sorted.reindex(columns=cols)
# Out:
# <ipython-input-144-4d7761e166d0>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_rules_sorted['antecedent'] = df_rules_sorted['antecedent'].astype(str).str.replace(r'\(|\)|,', '')

# %%
df_rules_sorted
# Out:
#                       antecedent                       consequent_1  \
# 0       'bag of organic bananas'               organic hass avocado
# 1       'bag of organic bananas'               organic hass avocado
# 2       'bag of organic bananas'                organic raspberries
# 3         'organic strawberries'             bag of organic bananas
# 4       'bag of organic bananas'               organic baby spinach
# 5         'organic strawberries'             bag of organic bananas
# 6         'organic strawberries'             bag of organic bananas
# 7         'organic baby spinach'             bag of organic bananas
# 8       'bag of organic bananas'               organic navel orange
# 9                       'banana'                 organic fuji apple
# 10      'bag of organic bananas'                   organic broccoli
# 11                      'banana'                        roma tomato
# 12                      'banana'                        red peppers
# 13                      'banana'                        blueberries
# 14                      'banana'                    clementines bag
# 15                       'limes'                   jalapeno peppers
# 16                       'limes'                   bunched cilantro
# 17                      'banana'                 orange bell pepper
# 18                      'banana'  boneless skinless chicken breasts
# 19  'sparkling water grapefruit'               lime sparkling water
# 20                      'banana'                    red vine tomato
# 21                      'banana'             100% whole wheat bread
# 22      'bag of organic bananas'    organic unsweetened almond milk
# 23      'bag of organic bananas'                      hass avocados
# 24                      'banana'                     cucumber kirby
#
#             consequent_2 confidence_level
# 0    organic raspberries          0.49353
# 1   organic strawberries         0.434307
# 2   organic strawberries          0.37037
# 3    organic raspberries         0.343733
# 4   organic strawberries         0.339503
# 5   organic hass avocado         0.276637
# 6   organic baby spinach         0.249575
# 7   organic strawberries         0.181959
# 8                    nan         0.179087
# 9                    nan         0.166195
# 10                   nan         0.156024
# 11                   nan         0.152683
# 12                   nan         0.152677
# 13                   nan         0.145472
# 14                   nan         0.144961
# 15                   nan           0.1423
# 16                   nan         0.140618
# 17                   nan         0.134004
# 18                   nan         0.133675
# 19                   nan         0.126418
# 20                   nan         0.125597
# 21                   nan         0.124487
# 22                   nan         0.123988
# 23                   nan         0.123006
# 24                   nan           0.1124

# %%
# save results to a .csv file in data folder
df_rules_sorted.to_csv('data/rules.csv', index = False)

# %%
all_orders_full.head()
# Out:
#    product_id                product_name  aisle_id  department_id  order_id  \
# 0           1  chocolate sandwich cookies        61             19      6695
# 1           1  chocolate sandwich cookies        61             19     48361
# 2           1  chocolate sandwich cookies        61             19     63770
# 3           1  chocolate sandwich cookies        61             19     75339
# 4           1  chocolate sandwich cookies        61             19    240996
#
#    add_to_cart_order  reordered  quantity
# 0                  7          1       1.0
# 1                  9          0       1.0
# 2                  4          0       1.0
# 3                  9          0       1.0
# 4                  3          1       1.0

# %%
# create lists of items and concatenate into one
antecedents = df_rules_sorted['antecedent'].to_list()
consequent_1 = df_rules_sorted['consequent_1'].to_list()
consequent_2 = df_rules_sorted['consequent_2'].to_list()
full_item_list = antecedents + consequent_1 + consequent_2
clean_list = [x for x in full_item_list if str(x) != 'nan']
used = set()
unique_items = [x for x in clean_list if x not in used and (used.add(x) or True)]

# %%
# loop through the list and find order in which they were added to a cart
cart_order = []

for item in unique_items:
    if item in all_orders_full['product_name']:
        print(True)
    else:
        print(False)
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False

# %%
check = [all_orders_full.loc[lambda all_orders_full: all_orders_full['product_name'] == 'bananas']]

# %%
unique_items
# Out:
# [('bag of organic bananas',),
#  ('organic strawberries',),
#  ('organic baby spinach',),
#  ('banana',),
#  ('limes',),
#  ('sparkling water grapefruit',),
#  'organic hass avocado',
#  'organic raspberries',
#  'bag of organic bananas',
#  'organic baby spinach',
#  'organic navel orange',
#  'organic fuji apple',
#  'organic broccoli',
#  'roma tomato',
#  'red peppers',
#  'blueberries',
#  'clementines bag',
#  'jalapeno peppers',
#  'bunched cilantro',
#  'orange bell pepper',
#  'boneless skinless chicken breasts',
#  'lime sparkling water',
#  'red vine tomato',
#  '100% whole wheat bread',
#  'organic unsweetened almond milk',
#  'hass avocados',
#  'cucumber kirby',
#  'organic strawberries']
