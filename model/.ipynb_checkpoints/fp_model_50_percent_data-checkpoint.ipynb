# %% [markdown]
# #### FP-Growth Algorithm Model on 30% of the Data

# %%
# imports
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import random
from fpgrowth_py import fpgrowth
import pyfpgrowth
import random
import matplotlib.pyplot as plt

# %%
# reading random 50% of the prior orders data
p = 0.50
order_prior = pd.read_csv('data/order_products__prior.csv', header = 0,  skiprows=lambda i: i>0 and random.random() > p)

# %%
# reading random 50% of train orders data
p = 0.50
order_train = pd.read_csv('data/order_products__train.csv', header = 0,  skiprows=lambda i: i>0 and random.random() > p)

# %%
# reading in products data
products = pd.read_csv('data/products.csv')

# %% [markdown]
# **Merge products and prior Orders**

# %%
prod_orders_prior = pd.merge(products, order_prior,  on = 'product_id') # marge products and orders

# %% [markdown]
# **Merge products and train Orders**

# %%
prod_orders_train = pd.merge(products, order_train,  on = 'product_id') # merge products and train orders

# %% [markdown]
# **Concatenate and preprocess prior and train Orders**

# %%
orders_train_prior = pd.concat([prod_orders_train, prod_orders_prior], ignore_index = True, sort = False)

# %%
# lower case product names
orders_train_prior['product_name'] = orders_train_prior['product_name'].str.lower()

# %%
# take out commas in product names
orders_train_prior['product_name'] = orders_train_prior['product_name'].str.replace(",","")

# %%
# group products by order_id into a df
df_all_orders = orders_train_prior.groupby('order_id')['product_name'].agg([('product_name', ','.join)]).reset_index()

# %%
# reset order_id as index
df_all_orders.set_index('order_id', inplace=True)

# %%
# split results product sets by comma
df_orders_split = df_all_orders.product_name.apply(lambda x: x.split(','))

# %%
# create a dataframe
df_orders = pd.DataFrame(df_orders_split)

# %%
# Identify products with minimum support level
patterns_all = pyfpgrowth.find_frequent_patterns(df_orders['product_name'], 1000)

# %%
patterns_all
# Out:
# {('pad thai brown rice noodles',): 1000,
#  ('cheddar cheese medium',): 1001,
#  ('orange soda',): 1001,
#  ('vanilla protein protein shake',): 1002,
#  ('original spread',): 1002,
#  ('caribbean coconut gelato',): 1002,
#  ('gin gins original chewy ginger candy',): 1002,
#  ('sweet potato fries with salt',): 1002,
#  ('organic baby food banana beet & blueberry',): 1003,
#  ('frozen whole strawberries',): 1003,
#  ('white pita',): 1004,
#  ('organic sliced provalone cheese',): 1005,
#  ('cream top with chocolate on the bottom yogurt',): 1005,
#  ('original glass cleaner',): 1005,
#  ('original high efficiency liquid laundry detergent',): 1005,
#  ('rising crust supreme (sausage pepperoni red peppers green peppers onions black olives) frozen pizza',): 1005,
#  ('lightly salted brown rice cakes',): 1006,
#  ('no pulp orange juice',): 1006,
#  ('super foods/organic apples spinach peas & broccoli + super chia snack pouch',): 1006,
#  ('one bun multigrain whole grain pita',): 1007,
#  ('vanilla coffee concentrate',): 1007,
#  ('snack size vanilla yogurt raisins',): 1007,
#  ('ultra thin sliced provolone cheese',): 1009,
#  ('revive zero vitamin water',): 1009,
#  ('cold-pressed organic grapefruit',): 1010,
#  ('unprocessed american singles colby-style cheese',): 1010,
#  ('vegetable fried rice',): 1010,
#  ('belgian endive',): 1010,
#  ('rice thins brown rice snack crackers',): 1011,
#  ('pepper greens',): 1011,
#  ('mint chocolate cookie ice cream',): 1012,
#  ('oreo  ice cream sandwiches',): 1012,
#  ('fajita seasoning',): 1013,
#  ('organic 100% grapefruit  juice',): 1013,
#  ('enchilada black bean vegetable',): 1013,
#  ('coconut water organic',): 1013,
#  ('kefir cultured milk smoothie whole milk sublime slime lime',): 1014,
#  ('organic vitality snack chia squeeze blackberry bliss',): 1014,
#  ('lactose free cream cheese',): 1015,
#  ('pink virgin lemonade',): 1015,
#  ('milano double chocolate cookies',): 1016,
#  ('natural emmentaler swiss cheese',): 1016,
#  ('lemon love juice drink',): 1016,
#  ('organic original hot oatmeal',): 1016,
#  ('balsamic vinaigrette dressing',): 1016,
#  ('unsweetened whole milk peach greek yogurt',): 1017,
#  ('oven baked cheddar & sour cream potato crisps',): 1017,
#  ('light vanilla soymilk',): 1017,
#  ('raspberry cereal',): 1018,
#  ('unsweetened whole milk strawberry yogurt',): 1019,
#  ('smart dogs veggie hot dogs',): 1019,
#  ('buttermilk pancakes 8 count',): 1019,
#  ('sesame seed',): 1020,
#  ('organic honey',): 1020,
#  ('organic soft white bread',): 1020,
#  ('cold brew coffee nitro can',): 1020,
#  ('morning rounds muesli fruit & grain buns',): 1021,
#  ('organic european style sweet unsalted butter',): 1021,
#  ('diet tonic water',): 1023,
#  ('reduced-fat soft cream cheese',): 1023,
#  ('organic pine nuts',): 1023,
#  ('southwest chopped salad kit with dressing',): 1023,
#  ('thick cut bacon',): 1023,
#  ('oatmeal raisin walnut energy bar',): 1023,
#  ('chardonnay wine',): 1025,
#  ('sparkling probiotic drink strawberry acai coconut',): 1025,
#  ('mashed potatoes',): 1025,
#  ('sea salt',): 1025,
#  ('cool mint chocolate',): 1026,
#  ('lite balsamic dressing',): 1027,
#  ('roasted red pepper hommus',): 1027,
#  ('shredded red cabbage',): 1027,
#  ('organic chunky vegetable soup',): 1028,
#  ('mango sorbet pops',): 1028,
#  ('organic gluten free sea salt by the seashore multigrain tortilla chips',): 1028,
#  ('cup noodles chicken flavor',): 1029,
#  ('wild sardines in extra virgin olive oil',): 1029,
#  ('bread crumbs',): 1030,
#  ('sparkling mineral water natural lemon flavor',): 1030,
#  ('trop50 no pulp orange juice',): 1030,
#  ('sesame blues corn tortilla chips',): 1030,
#  ('pistachios',): 1031,
#  ("crispy chick'n sliders",): 1031,
#  ('classic green tea',): 1031,
#  ('roasted chicken breast',): 1031,
#  ('kale',): 1032,
#  ('large grade a eggs',): 1032,
#  ('vegetable pot pie',): 1032,
#  ("shepherd's pie",): 1033,
#  ('lower sugar instant oatmeal  variety',): 1033,
#  ('club delight sausage egg & cheese sandwiches',): 1033,
#  ('light very vanilla',): 1033,
#  ('lemon sparkling mineral water',): 1033,
#  ('sweet potato littles',): 1034,
#  ('extra sharp aged cheddar cheese slices',): 1035,
#  ('sparkling probiotic drink mango coconut',): 1035,
#  ('authentic french brioche rolls',): 1035,
#  ('chunk light tuna',): 1036,
#  ('gluten free whole grain bagels',): 1036,
#  ('tomato basil sauce',): 1036,
#  ('spicy brown mustard',): 1037,
#  ('chicken drumsticks',): 1037,
#  ('old fashioned oatmeal',): 1037,
#  ('red bell peppers',): 1038,
#  ('unsweetened vanilla cashew milk',): 1040,
#  ('queso fresco',): 1040,
#  ('bathroom tissue double rolls',): 1040,
#  ('unsweetened iced tea',): 1040,
#  ('shelled pistachios',): 1041,
#  ('crackers crispy cheddar',): 1041,
#  ('snack pack mini classic',): 1041,
#  ('white paper towels',): 1042,
#  ('american blend salad',): 1042,
#  ('sweet potatoes stage 2',): 1042,
#  ('all purpose cleaner',): 1043,
#  ('ezekiel 4:9 flax sprouted grain bread',): 1043,
#  ('organic blues bread with blue cornmeal crust',): 1043,
#  ('natural buttermilk pancake & waffle mix',): 1043,
#  ('super soft flour tortillas fajita size 20 ct',): 1043,
#  ('almond & apricot bar',): 1044,
#  ('sprouted wheat cinnamon raisin bagels',): 1044,
#  ('organic mesa sunrise cereal',): 1045,
#  ('organic french roast ground coffee',): 1047,
#  ('homestyle breaded chicken breast tenders',): 1047,
#  ('olive oil & aloe vera hand soap',): 1048,
#  ('100% whole wheat',): 1048,
#  ('organic smoked chicken breast',): 1048,
#  ('nilla wafers',): 1049,
#  ('high pulp orange juice',): 1049,
#  ('italian sausage pizza',): 1049,
#  ('premium sweet petites carrots',): 1049,
#  ('chicken salad',): 1049,
#  ("fakin' bacon organic smoky tempeh strips",): 1052,
#  ('pomegranate blackberry probiotics juice drink',): 1052,
#  ('chicken stock',): 1053,
#  ('string cheese',): 1053,
#  ('rise krisipies toasted rice cereal',): 1053,
#  ('chocolate hazelnut butter blend',): 1054,
#  ('2% chocolate milk',): 1055,
#  ('uncured italian dry salami',): 1056,
#  ('pumpkin & spinach stage 2 baby food',): 1056,
#  ('olive hummus',): 1057,
#  ('one ply choose a size big roll paper towel rolls',): 1058,
#  ('poppy seed dressing',): 1058,
#  ('original applesauce',): 1059,
#  ('raisin bran',): 1060,
#  ('original cherry orchard yogurt',): 1060,
#  ('pita bread',): 1060,
#  ('jet-puffed marshmallows',): 1060,
#  ('premium fish sauce',): 1061,
#  ('pineapple yogurt 2%',): 1061,
#  ('chocolate crepes',): 1061,
#  ('natural lemon flavor sparkling mineral water',): 1061,
#  ('simply stock organic vegetable unsalted stock',): 1062,
#  ('grape-nuts cereal',): 1062,
#  ('bean & rice chips nacho',): 1062,
#  ('passion fruit',): 1062,
#  ('potted basil',): 1062,
#  ('dark chocolate chips',): 1063,
#  ('medium roast ground coffee',): 1064,
#  ('chocolate whole grain graham snacks bunny grahams',): 1064,
#  ('recipe secrets onion soup & dip mix',): 1065,
#  ('super antioxidant green tea',): 1065,
#  ('feta cheese',): 1065,
#  ('organic bay leaves',): 1066,
#  ('frozen breaded bagged chicken nuggets',): 1066,
#  ('unsweetened chocolate almond breeze almond milk',): 1066,
#  ('organic hoisin sauce',): 1066,
#  ('zero go-go mixed berry vitamin water',): 1067,
#  ('organic classic sea salt  oven crinkles fries',): 1068,
#  ('european style salted butter',): 1068,
#  ('swedish meatballs',): 1069,
#  ('cavatappi no. 87 macaroni',): 1070,
#  ('organic heritage flakes cereal',): 1071,
#  ('premium sliced bacon',): 1072,
#  ('raw mild cheddar cheese',): 1072,
#  ('steamfresh super sweet corn',): 1072,
#  ('ancient grain granola cranberry pecan',): 1073,
#  ('quiche lorraine',): 1073,
#  ('organic pack peasant bread',): 1073,
#  ('the original multi grain bread',): 1073,
#  ('peanut butter ice cream cup',): 1074,
#  ('coarse sea salt',): 1075,
#  ("builder's chocolate peanut butter bar",): 1076,
#  ('mocha frappucino chilled coffee drink',): 1077,
#  ('shaved parmesan',): 1077,
#  ('premium organic strawberry spread',): 1077,
#  ('expeller pressed coconut oil spray',): 1077,
#  ('organic chard green',): 1078,
#  ('egg salad',): 1079,
#  ('green curry paste',): 1080,
#  ('brown sugar maple oatmeal with ancient grains',): 1080,
#  ('chocolate milk frozen pops',): 1081,
#  ('farmhouse hearty white bread',): 1081,
#  ('uncured hard salami',): 1081,
#  ('tomato and basil bombolina pasta sauce',): 1082,
#  ('caesar salad kit',): 1082,
#  ('natural bliss salted caramel flavor all-natural coffee creamer',): 1083,
#  ('carrot sticks',): 1085,
#  ('organic gluten free quinoa spaghetti',): 1085,
#  ('raspberry essence water',): 1085,
#  ('organic brown rice crisps cereal',): 1086,
#  ('fresh roasted tomate & chile asado medium salsa',): 1086,
#  ('tomatoes sauce',): 1086,
#  ('sweet kale chopped salad',): 1086,
#  ('natural california raisins',): 1087,
#  ('baby brussels sprouts',): 1089,
#  ('tomato basil cooking sauce',): 1089,
#  ('original style yoghurt plain',): 1089,
#  ('low fat key lime blended greek yogurt',): 1089,
#  ('tostitos  scoops',): 1089,
#  ('vegetable broth low sodium',): 1090,
#  ('citrus dish soap',): 1090,
#  ('pomegranate on the bottom non-fat greek yogurt',): 1090,
#  ('organic 100% whole wheat loaf',): 1090,
#  ('original egg substitute',): 1090,
#  ('large enriched bread',): 1090,
#  ('cafe cuisine sesame chicken',): 1091,
#  ('organic thompson raisins',): 1091,
#  ('max gel clog remover',): 1092,
#  ('italian sparkling pomegranate and orange soda',): 1093,
#  ('black beans refried beans',): 1093,
#  ('tofu scramble',): 1093,
#  ('organic gluten free fusilli',): 1093,
#  ('kale krunch the original quite cheezy',): 1095,
#  ('krinkle cut salt & fresh ground pepper potato chips',): 1096,
#  ('rich & hearty chicken & homestyle noodles soup',): 1097,
#  ('almond breeze chocolate almond milk',): 1097,
#  ('organic baby lettuces',): 1097,
#  ('zero calorie sweetener',): 1098,
#  ('100% lime juice',): 1098,
#  ('california lemonade',): 1099,
#  ('bite size tortilla chips',): 1099,
#  ('organic cultured sour cream',): 1100,
#  ('moroccan mint herbal tea',): 1101,
#  ('blueberry beet & brown rice cakes',): 1101,
#  ('wheat thins original',): 1101,
#  ('of maine fresh frozen wild blueberries',): 1102,
#  ('pure life purified water',): 1104,
#  ('gourmet pizza three cheese gluten free',): 1104,
#  ('tamari gluten free soy sauce reduced sodium',): 1105,
#  ('ginger beer',): 1106,
#  ('natural black cherry gels gelatin free snacks',): 1108,
#  ('vegetable chips taro sea salt',): 1108,
#  ('chocolate protein soy & dairy protein shake',): 1109,
#  ('reduced fat irish butter',): 1109,
#  ('olive oil & vinegar dressing',): 1110,
#  ('multi grain crispbread',): 1110,
#  ('white cheddar snack crackers cheddar bunnies',): 1111,
#  ('chicken fried rice',): 1111,
#  ('squeeze real mayonnaise',): 1111,
#  ('original sour cream',): 1111,
#  ('mediterranee strawberry yogurt',): 1112,
#  ('salted caramel lean protein & fiber bar',): 1112,
#  ('fridge and freezer baking soda pack',): 1112,
#  ('compostable coffee filters',): 1113,
#  ('lucky charms cereal',): 1113,
#  ('usda aa extra large eggs',): 1114,
#  ('veggie cheese & pretzel snack pac prepacked',): 1115,
#  ('organic strained tomatoes',): 1115,
#  ('organic chicken & vegetable potstickers',): 1116,
#  ('organic beef bone broth',): 1116,
#  ('organic celery',): 1117,
#  ('thin and crispy corn tortilla chips',): 1117,
#  ('zero calorie cream soda',): 1118,
#  ('oyster crackers',): 1118,
#  ('purple cauliflower',): 1118,
#  ('garlic bread',): 1119,
#  ('parmesan cheese crisps',): 1120,
#  ('black beans reduced sodium',): 1121,
#  ('hearts of palm',): 1121,
#  ('oats & chocolate chewy bars',): 1122,
#  ('ginger yuzu scented dish soap',): 1122,
#  ('organic sriracha hummus',): 1122,
#  ('organic sweet potato fries',): 1122,
#  ('original 7 grain crackers',): 1123,
#  ('crimini delight mushrooms',): 1123,
#  ('turkey franks',): 1124,
#  ('organic brown rice pasta spirals',): 1124,
#  ('fennel',): 1125,
#  ('strawberry and banana fruit puree',): 1125,
#  ('almond breeze almond coconut milk',): 1125,
#  ('flank steak',): 1126,
#  ('whole grain organic waffles totally original',): 1127,
#  ('mighty 4 kale strawberry amaranth & greek yogurt tots snack',): 1127,
#  ('red delicious apples',): 1128,
#  ('organic bran flakes cereal',): 1128,
#  ('creamy natural peanut butter and flaxseed',): 1129,
#  ('water mineral',): 1129,
#  ('genuine brewed rice vinegar',): 1130,
#  ('organic honey graham crackers',): 1130,
#  ('multigrain sandwich bread',): 1131,
#  ('gluten free quick cooking oats',): 1132,
#  ('le gruyere cheese',): 1132,
#  ('super natural organic whole milk',): 1133,
#  ('lactose free low fat vanilla yogurt',): 1134,
#  ('triscuit baked whole grain wheat rosemary & olive oil',): 1134,
#  ('whipped cream cheese spread',): 1135,
#  ('regular pork sausage tube',): 1135,
#  ("organic bernie's farm macaroni & cheese",): 1135,
#  ('velveeta shells & cheese pasta',): 1135,
#  ("annie's bunny fruit snacks variety",): 1135,
#  ('whole natural value pack almonds',): 1136,
#  ('blueberry blaze trail mix',): 1136,
#  ('zucchini squash',): 1136,
#  ('pork breakfast sausage',): 1137,
#  ('snack bags',): 1137,
#  ('waffle cut sweet potato seasoned fries',): 1138,
#  ('organic reduced fat 2% cottage cheese',): 1138,
#  ('little yums spinach apple and kale teething wafers',): 1138,
#  ('traditional basil pesto sauce',): 1138,
#  ('sweet & salty kettlecorn',): 1138,
#  ('organic hass avocado bag',): 1139,
#  ('nacho cheese chips',): 1139,
#  ('brown extra large grade aa eggs',): 1139,
#  ('fiber & protein organic pears raspberries butternut squash & carrots snack',): 1140,
#  ('roasted seaweed snacks',): 1141,
#  ('organic vanilla whole milk yogurt',): 1141,
#  ('traditional scottish style smoked salmon',): 1142,
#  ('total with strawberry yogurt',): 1142,
#  ('low fat no chicken noodle soup',): 1143,
#  ('vanilla bean chia pod',): 1143,
#  ('perrier lime',): 1143,
#  ('coke zero diet soda',): 1143,
#  ('organic blueberries clamshell',): 1145,
#  ('pepperoni pizza rolls',): 1146,
#  ('mediterranean thin crust pizza',): 1146,
#  ('all whites 100% liquid egg whites',): 1146,
#  ("s'mores chocolate ice cream",): 1147,
#  ('breaded fish sticks',): 1148,
#  ('chocolate hazelnut butter',): 1148,
#  ('mint chocolate chip frozen greek yogurt bars',): 1148,
#  ('beast burger',): 1149,
#  ('organic beefsteak tomato',): 1151,
#  ('zucchini noodles',): 1151,
#  ('organic  sweet & salty peanut pretzel granola bars',): 1151,
#  ('ice cream chocolate mocha chip',): 1151,
#  ('original tofurky deli slices',): 1152,
#  ('original pepperoni',): 1152,
#  ('brazilian cheese bread original cheddar and parmesan',): 1152,
#  ('instant coffee',): 1153,
#  ('genuine chocolate flavor syrup',): 1153,
#  ('whipped butter',): 1153,
#  ('butter lettuce',): 1153,
#  ('black bean tamale verde',): 1153,
#  ('low moisture part skim mozzarella string cheese',): 1153,
#  ('california veggie burger',): 1154,
#  ('organic cultured low fat 1% cottage cheese',): 1154,
#  ('chocolate coconut chew flavored bar',): 1155,
#  ('organic pitted prunes',): 1155,
#  ('brownberry natural wheat bread',): 1155,
#  ('almond snack crackers',): 1156,
#  ('gluten free chocolate chunk cookies',): 1156,
#  ('april fresh liquid fabric softener',): 1156,
#  ('traditional snack mix',): 1157,
#  ('sweet greens and lemon vegetable and fruit juice blend',): 1157,
#  ('potato chips sweet potato',): 1157,
#  ('kettle cooked sea salt & vinegar potato chips',): 1157,
#  ("stand 'n stuff taco shells",): 1158,
#  ('frozen blueberries',): 1158,
#  ('sweet batard',): 1158,
#  ('light mayonnaise',): 1159,
#  ('gluten free vanilla granola',): 1159,
#  ('chewy granola bars variety pack',): 1160,
#  ('pretzel sticks gluten free',): 1160,
#  ('organic apple sauce',): 1160,
#  ('eggo blueberry waffles',): 1161,
#  ('pears kale & spinach organic baby food',): 1161,
#  ('organic fettuccine',): 1161,
#  ("dairy free gluten free cheeze lover's pizza",): 1161,
#  ('organic lettuce',): 1161,
#  ('all natural maple almond butter',): 1161,
#  ('all purpose crushed tomatoes',): 1161,
#  ('ginger snap cookies',): 1161,
#  ('hummus',): 1162,
#  ('vanilla soy milk',): 1163,
#  ('frosted berry strawberry toaster pastries',): 1163,
#  ('low fat chocolate milk',): 1163,
#  ('naturally hickory smoked thick cut bacon',): 1163,
#  ('asian pears',): 1164,
#  ('7 sprouted grains bread',): 1164,
#  ('gluten free rice chex',): 1164,
#  ('sweet & salty nut peanut granola bars',): 1165,
#  ('rice krispies treats original crispy marshmallow squares',): 1165,
#  ('organic sweet relish',): 1165,
#  ('french roast whole bean coffee',): 1166,
#  ("chocolate mint builder's bar",): 1166,
#  ('4 cheese mexican fine cut shredded cheese',): 1167,
#  ('chicken breast tenders',): 1167,
#  ('hazelnut spread with cocoa',): 1168,
#  ('double chocolate chip cookies',): 1168,
#  ('gluten free multigrain bread',): 1168,
#  ('milk free better than sour cream',): 1169,
#  ('wild wonders gourmet medley tomatoes',): 1169,
#  ('organic cinnamon graham crackers',): 1169,
#  ('regular',): 1170,
#  ('organic gluten free & wheat free pumpkin spice waffles',): 1171,
#  ('organic vanilla kefir',): 1171,
#  ('refresh herbal tea',): 1172,
#  ('semi soft part-skim cheese',): 1172,
#  ('mini babybel mozzarella cheese',): 1172,
#  ('deli fresh honey smoked turkey breast 98% fat free gluten free',): 1173,
#  ('smooth operator natural peanut butter',): 1173,
#  ('select-a-size white giant roll paper towels',): 1174,
#  ('sliced beets no salt added',): 1174,
#  ('dark brown sugar',): 1174,
#  ('butter with canola oil spread',): 1174,
#  ('organic chunky tomato bisque soup',): 1175,
#  ('unsweetened organic coconut milk light',): 1175,
#  ('organic hazelnut spread',): 1176,
#  ('low sodium black beans',): 1176,
#  ('midnight moon',): 1177,
#  ('organic sweet pea',): 1177,
#  ('brown rice black-eyed peas and veggies bowl',): 1178,
#  ('unsweetened coconut water',): 1179,
#  ('organic yellow zucchini',): 1179,
#  ('mango flavor probiotic juice drink',): 1181,
#  ('organic stage 2 carrots baby food',): 1183,
#  ('beefsteak tomatoes',): 1184,
#  ('plain soymilk creamer',): 1184,
#  ('milk whole',): 1184,
#  ('baked mini beef meatballs',): 1184,
#  ('hemp hearts raw shelled hemp seeds',): 1184,
#  ('organic diced fire roasted tomatoes',): 1185,
#  ('mixed grapes',): 1185,
#  ('chocolate peppermint stick bar',): 1186,
#  ('disinfecting wipes fresh scent',): 1188,
#  ('peach mango salsa',): 1189,
#  ('jet puffed miniature marshmallows',): 1189,
#  ('organic creamy butternut squash soup',): 1190,
#  ('organic spaghetti',): 1190,
#  ('peanut milk chocolate xxl bag',): 1190,
#  ('organic greek fat free plain yogurt',): 1192,
#  ('alaskan salmon burgers',): 1193,
#  ('natural deli style sliced swiss cheese',): 1193,
#  ('chocolate fudge brownie ice cream',): 1194,
#  ('tomato medley',): 1194,
#  ('raspberries dark chocolate bar',): 1196,
#  ('cheddar puffs',): 1196,
#  ('real french vinaigrette dressing',): 1196,
#  ('original potato crisps',): 1196,
#  ('dry roasted lightly salted peanuts',): 1196,
#  ('deli fresh rotisserie seasoned chicken breast',): 1197,
#  ('original black bean with sea salt bean chips',): 1197,
#  ('heavy duty scrub sponges',): 1198,
#  ('oh my yog! organic wild quebec blueberry cream top yogurt & fruit',): 1199,
#  ('salame italian dry',): 1199,
#  ('fruit spread deluxe strawberry',): 1199,
#  ('strawberry gelatin',): 1199,
#  ('garden salsa multigrain chips',): 1201,
#  ('vegetarian grain meat sausages italian - 4 ct',): 1201,
#  ('organic chicken & wild rice soup',): 1201,
#  ('reduced fat milk 2%',): 1202,
#  ('deluxe everything bagels',): 1202,
#  ('bathroom tissue 1‑ply 1000 sheet rolls',): 1202,
#  ('good belly probiotics juice drink blueberry acai flavor',): 1204,
#  ('natural muenster cheese',): 1205,
#  ('ultra plush 3 ply toilet paper 12 double rolls',): 1205,
#  ('whole wheat blueberry fig bars',): 1205,
#  ('bread & butter pickle chips',): 1206,
#  ('squash & sweet peas stage 2',): 1206,
#  ('15 grain whole grain bread',): 1207,
#  ('santa fe fiesta salad',): 1207,
#  ('premium grapefruit large',): 1209,
#  ('cracked wheat sourdough loaf',): 1210,
#  ('uncooked medium flour tortillas',): 1210,
#  ('vanilla whey protein powder',): 1211,
#  ('quick 1 minute oatmeal',): 1211,
#  ('baguette sourdough',): 1211,
#  ('roasted salted almonds',): 1211,
#  ('steel cut irish oatmeal',): 1212,
#  ('bag of oranges',): 1213,
#  ('chicken nuggets',): 1213,
#  ('organic cranberry pomegranate juice',): 1213,
#  ('original tortilla strips',): 1213,
#  ('natural laundry detergent free & clear 33',): 1215,
#  ('tater puffs',): 1215,
#  ('nutri-grain soft baked strawberry cereal breakfast bars',): 1217,
#  ('blueberry crisp energy bar',): 1217,
#  ('soy sauce',): 1218,
#  ('all natural no stir creamy almond butter',): 1220,
#  ('asparagus spears',): 1220,
#  ('light & fit strawberry non fat greek yogurt',): 1220,
#  ('sparkling peach',): 1220,
#  ('organic appleberry applesauce on the go',): 1220,
#  ('low sodium refried black beans',): 1220,
#  ('peanut butter egg white protein bar',): 1222,
#  ('organic infant formula with iron',): 1224,
#  ('original strawberry banana yogurt',): 1224,
#  ('peppered turkey jerky',): 1226,
#  ('four fruits preserves',): 1227,
#  ('gluten free classic hamburger buns',): 1227,
#  ('mocha almond fudge minis almond milk frozen dessert',): 1227,
#  ('100% orange juice',): 1229,
#  ('complete™ actionpacs™ fresh scent dishwasher detergent',): 1230,
#  ('cold-pressed organic orange',): 1230,
#  ('sourdough deli bread',): 1230,
#  ('organic broccoli slaw',): 1231,
#  ('microwave in bag green beans',): 1232,
#  ('100% natural diced tomatoes',): 1232,
#  ('breakfast blend medium roast ground coffee',): 1232,
#  ('purified drinking water',): 1233,
#  ('lemons',): 1233,
#  ('grade a organic large brown eggs',): 1233,
#  ('diet peach tea',): 1234,
#  ('kidney beans',): 1234,
#  ('defense up cold pressed fruit smoothie',): 1235,
#  ('single serve cheese pizza',): 1235,
#  ('organic flax plus multibran flakes',): 1235,
#  ('100% whole wheat pre-sliced sandwich thins',): 1235,
#  ('mango sorbet',): 1237,
#  ('variety diet tea',): 1237,
#  ('mayonnaise',): 1240,
#  ('original hawaiian sweet rolls',): 1240,
#  ('ultra original scent dishwashing liquid',): 1240,
#  ('blue machine boosted 100% juice smoothie',): 1240,
#  ('strained non fat orange & ginger yogurt',): 1241,
#  ('loose white button mushrooms',): 1242,
#  ('liquid aminos all purpose seasoning',): 1242,
#  ('watercress bunch',): 1242,
#  ('small compostable waste bag',): 1243,
#  ('minced ginger',): 1244,
#  ('gluten free honey almond granola',): 1245,
#  ('natural mini pork pepperoni',): 1245,
#  ('organic nonfat greek yogurt with lemon',): 1246,
#  ('organic ranch dressing',): 1247,
#  ('grilled chicken strips',): 1247,
#  ('original bbq sauce',): 1247,
#  ('mango',): 1248,
#  ('chewy 25% low sugar chocolate chip granola',): 1249,
#  ('cocktail style cubes  spring water ice',): 1249,
#  ('natural shredded mexican style four cheese',): 1250,
#  ('free and gentle high efficiency liquid laundry detergent',): 1250,
#  ('prosciutto di san daniele',): 1250,
#  ('ultra thin slices sharp cheddar cheese',): 1251,
#  ('hand picked pomegranate seeds/arils',): 1252,
#  ('sea salt flakes original',): 1253,
#  ('eggo buttermilk waffles',): 1254,
#  ('strained tomatoes',): 1254,
#  ('real sweet potato vegetable chips',): 1256,
#  ('small curd lowfat 2% milkfat cottage cheese',): 1256,
#  ('butter with olive oil & sea salt',): 1256,
#  ('the original worcestershire sauce',): 1257,
#  ('sparkling apple juice',): 1257,
#  ('jalapeno cilantro salsa',): 1257,
#  ("mandarin orange crispy chick'n",): 1259,
#  ('pesto pizza',): 1259,
#  ('natural anticavity silly strawberry fluoride toothpaste for children',): 1259,
#  ('organic atage 3 nibbly fingers mangoes carrots',): 1259,
#  ('zero calorie cola soda',): 1259,
#  ('xx espresso iced coffee with almond milk',): 1259,
#  ('almond milk ricotta',): 1260,
#  ('tater tots',): 1260,
#  ('olive oil cooking spray',): 1262,
#  ('mini pretzels',): 1262,
#  ('organic sunny days apple snack bars',): 1264,
#  ('organic sensible sipper apple juice',): 1264,
#  ('wild sockeye salmon',): 1265,
#  ('tuscan kale & quinoa salad',): 1265,
#  ('parmesan cheese',): 1265,
#  ('muffins flax wild blueberry',): 1266,
#  ('condensed cream of mushroom soup',): 1267,
#  ('organic spinach & feta dinner sausage',): 1268,
#  ('beef loin new york strip steak',): 1269,
#  ('organic unsweetened soy milk beverage',): 1270,
#  ('chili powder',): 1270,
#  ('organic red heirloom pasta sauce',): 1270,
#  ('orange strawberry banana juice',): 1270,
#  ('wholesome breakfast blueberry banana',): 1272,
#  ('pure organic pineapple juice',): 1273,
#  ('mango tango fruit smoothie blend',): 1273,
#  ('fresh frozen wild blueberries',): 1274,
#  ('chicken pad thai with rice noodles',): 1274,
#  ('beyond beef fiesty crumble',): 1274,
#  ('original whipped topping',): 1274,
#  ('coconut almond creamer blend',): 1275,
#  ('french green beans',): 1275,
#  ('classic air-puffed vanilla flavored marshmallows',): 1275,
#  ('organic honey mustard',): 1276,
#  ('mini peanut butter sandwich crackers',): 1276,
#  ('original apple 100% juice',): 1276,
#  ('yokids organic strawberry banana lowfat yogurt squeeze',): 1278,
#  ('breakfast blend medium keurig brewed k-cups ground coffee',): 1279,
#  ('tortilla strips restaurant style',): 1279,
#  ('dark red kidney beans',): 1280,
#  ('taco seasoning mix original',): 1280,
#  ('french vanilla ice cream',): 1281,
#  ('pure cane granulated white sugar',): 1281,
#  ('pineapple spears',): 1281,
#  ('unsweetened cocoa powder',): 1282,
#  ('organic soba',): 1282,
#  ('oh my yog! madagascar vanilla trilayer yogyurt',): 1283,
#  ('fresh european style baby spinach',): 1284,
#  ('whole wheat cookies dark chocolate',): 1285,
#  ('100% whole wheat pre-sliced bagels',): 1285,
#  ('pineapple apple mint organic cold pressed juicd',): 1286,
#  ('pork chorizo',): 1287,
#  ('lightly salted kettle potato chips - sea salt',): 1287,
#  ('villagio marzano heavenly tomatoes',): 1287,
#  ('fresh mozzarella all-natural sliced cheese',): 1289,
#  ('organic plain yogurt',): 1289,
#  ('parmesan garlic pita chips',): 1289,
#  ('napa cabbage',): 1292,
#  ('malbec',): 1293,
#  ('seriously sharp cheddar cheese',): 1293,
#  ('dairy free french vanilla coconut milk creamer',): 1294,
#  ('pinto beans',): 1294,
#  ('cut tulips (choose color)',): 1294,
#  ('100% pomegranate juice',): 1294,
#  ('organic sproutofu silken tofu',): 1296,
#  ('coke',): 1296,
#  ('lemon ginger tea bags',): 1298,
#  ('radish',): 1298,
#  ('almond flour tortillas',): 1299,
#  ('dairy free hazelnut coconut milk creamer',): 1299,
#  ('original wheat thins crackers',): 1299,
#  ('vegetable medley',): 1301,
#  ('natural creamy peanut butter spread',): 1303,
#  ('wild blueberry preserves',): 1304,
#  ('light & lean spaghetti italiano with meatless meatballs',): 1304,
#  ('pico de gallo chunky salsa',): 1304,
#  ('diet ginger ale',): 1304,
#  ('indian paneer tikka',): 1305,
#  ('sliced almonds',): 1305,
#  ('meyer lemons',): 1305,
#  ('cleancare 1-ply double rolls toilet paper',): 1305,
#  ('organic apples carrots and parsnips puree',): 1305,
#  ('vegan apple maple breakfast sausage',): 1306,
#  ('organic  dried & unsulfured orchard select apricots',): 1307,
#  ('crushed garlic',): 1307,
#  ('little bites chocolate chip muffins',): 1307,
#  ('organic tarragon',): 1308,
#  ('red cabbage',): 1308,
#  ('acorn squash',): 1308,
#  ('sliced mushrooms',): 1308,
#  ('shredded parmigiano reggiano',): 1309,
#  ('organic strawberry lemonade',): 1309,
#  ('broccoli bunch',): 1309,
#  ('jasmine rice',): 1310,
#  ('sesame street organic mini blueberry pancakes',): 1312,
#  ('total 2% yogurt key lime',): 1312,
#  ('sparkling probiotic drink mojita lime mint coconut',): 1312,
#  ('organic low fat vegetable barley soup',): 1314,
#  ("m&m's vanilla lowfat yogurt",): 1314,
#  ('blueberry muffins',): 1315,
#  ('whole wheat eggo waffles',): 1315,
#  ('pecan nut & rice cracker snacks',): 1315,
#  ('yogurt pretzels',): 1315,
#  ('a+ cinnamon sweet potato pancakes',): 1316,
#  ('hot sauce',): 1316,
#  ('kefir cultured strawberry milk drink',): 1317,
#  ('pineapple strawberry sparkling water',): 1317,
#  ('dairy free coconut milk raspberry yogurt alternative',): 1318,
#  ('organic ground flaxseed',): 1319,
#  ('tortilla chips corn red hot blues',): 1320,
#  ('okra',): 1321,
#  ('black tea pyramids',): 1321,
#  ('hair bender whole bean coffee',): 1322,
#  ('organic eggplant',): 1323,
#  ('extra dark chocolate baking chips',): 1324,
#  ('organic hemp plus granola cereal',): 1326,
#  ('peaches large',): 1327,
#  ('gluten-free supergrain pasta organic corn & quinoa blend penne',): 1329,
#  ('organic brussels sprouts',): 1329,
#  ('flour tortillas soft taco',): 1329,
#  ('mighty 4 sweet potato blueberry millet & greek yogurt tots snack',): 1330,
#  ('smoked turkey breast',): 1330,
#  ('soft 10 grain bread',): 1331,
#  ('hickory smoked turkey breast',): 1331,
#  ('sparkling orange juice & prickly pear beverage',): 1331,
#  ('nonfat probiotic drinks',): 1332,
#  ('special k red berries cereal',): 1332,
#  ('low fat kefir cultured milk smoothie lowfat probiotic blueberry',): 1333,
#  ('iodized salt',): 1334,
#  ('organic popcorn',): 1334,
#  ('low fat cottage cheese',): 1335,
#  ('large brown free range eggs grade a',): 1335,
#  ('mild sliced cheddar cheese',): 1335,
#  ('hard salami',): 1335,
#  ('creamy peanut butter dark roasted',): 1335,
#  ('veganic sprouted brown rice cacao crisps',): 1336,
#  ('boneless chicken breast',): 1336,
#  ('original diced tomatoes & green chilies',): 1336,
#  ('frosted flakes',): 1337,
#  ('peanut butter & jelly fruit & nut food bar',): 1337,
#  ('apricots',): 1337,
#  ('quattro formaggi four cheeses pizza',): 1337,
#  ('passionberry bliss kombucha drink',): 1338,
#  ('crispix rice & corn cereal',): 1338,
#  ('organic cottage cheese classic',): 1338,
#  ('chunky guacamole',): 1339,
#  ('low fat split pea soup',): 1339,
#  ('extra long grain enriched rice',): 1340,
#  ('black forest ham',): 1341,
#  ('vitamin d organic milk',): 1341,
#  ('yogurt tubes blueberry',): 1341,
#  ('kosher salt',): 1342,
#  ('50/50 mix spring mix and baby spinach salad blend',): 1343,
#  ('french baguette bread',): 1344,
#  ('whole grain cheddar baked goldfish crackers',): 1346,
#  ('organic traditional gluten freen quinoa',): 1346,
#  ('organic go go apple peach applesauce',): 1348,
#  ('tlc cherry dark chocolate chewy granola',): 1348,
#  ('sprouted grain low sodium bread',): 1349,
#  ('mighty mango juice smoothie',): 1350,
#  ('fresh whole white mushrooms',): 1351,
#  ('lemon cake ice cream',): 1351,
#  ('organic cinnamon apple chips',): 1352,
#  ('organic crushed tomatoes with basil',): 1352,
#  ('mayonnaise classic',): 1352,
#  ('red onions',): 1353,
#  ('aged white cheddar popcorn',): 1355,
#  ('milk organic fat free',): 1355,
#  ('kitchen scrubber sponge',): 1355,
#  ('organic unsalted diced tomatoes',): 1356,
#  ('ciabatta',): 1357,
#  ('fresh basil',): 1358,
#  ('organic blended raspberry whole milk greek yogurt',): 1358,
#  ('honey bunny grahams',): 1358,
#  ('100% pineapple juice',): 1358,
#  ('barbeque potato chips',): 1358,
#  ('organic coconut oil',): 1358,
#  ('taboule salad',): 1359,
#  ('all natural french toast sticks',): 1362,
#  ('everyday 2 ply premium napkins',): 1364,
#  ('crushed red pepper',): 1365,
#  ('coconut blended greek yogurt',): 1365,
#  ('whole peeled tomatoes',): 1365,
#  ('brie',): 1366,
#  ('1% milkfat low fat buttermilk',): 1366,
#  ('black coffee',): 1367,
#  ('arborio white rice',): 1369,
#  ('split top wheat bread',): 1369,
#  ('organic red wine vineger',): 1370,
#  ('sea salt baked potato chips',): 1371,
#  ('lactose free yogurt plain',): 1372,
#  ('no calorie sweetener packets',): 1373,
#  ('sour batard',): 1373,
#  ('light & lean pasta & veggie bowl',): 1374,
#  ('crunchy organic dark roasted peanut butter',): 1376,
#  ('quick cooking rolled oats irish oatmeal',): 1376,
#  ('yo toddler organic strawberry banana whole milk yogurt',): 1377,
#  ('buttermilk biscuits',): 1378,
#  ('organic flour tortillas',): 1378,
#  ('organic cream of mushroom condensed soup',): 1379,
#  ('european style unsalted butter',): 1379,
#  ('no boil lasagna',): 1379,
#  ('100% mighty mango juice smoothie',): 1380,
#  ('organic sweet mini peppers',): 1380,
#  ('3 lb clementines',): 1383,
#  ('gluten free cinnamon raisin bread',): 1383,
#  ('cold brew coffee mocha',): 1383,
#  ('organic mango slices',): 1384,
#  ('organic z  mixed berry fruit rope',): 1384,
#  ('calm chamomile herbal tea',): 1385,
#  ('organic nonfat greek yogurt with raspberries',): 1385,
#  ('diet cola',): 1386,
#  ('shiitake mushroom',): 1387,
#  ('bread co pain au levain',): 1387,
#  ('ice',): 1388,
#  ('clean day basil hand soap',): 1389,
#  ("s'mores luna bar",): 1393,
#  ('greek whole milk blended blueberry yogurt',): 1393,
#  ('supremely spicy hummus',): 1393,
#  ('organic fire roasted corn',): 1393,
#  ('classic original hommus',): 1396,
#  ('snacks mango',): 1396,
#  ('100% whole wheat bagels',): 1396,
#  ('premium ice cubes',): 1396,
#  ('organic stage 2 broccoli pears & peas baby food',): 1397,
#  ('37% less sodium soy sauce',): 1400,
#  ("purely o's organic cereal",): 1400,
#  ('teriyaki chicken bowl',): 1400,
#  ('california clementines',): 1401,
#  ('cherries & almonds in dark chocolate 55% cocoa',): 1402,
#  ('ccnut raw cocoaminos',): 1402,
#  ('ravioli spinach & cheese',): 1403,
#  ('total 2% greek mixed berries yogurt',): 1403,
#  ('dried mangoes',): 1404,
#  ('whole milk with vitamin d',): 1404,
#  ("major dickason's blend whole bean coffee",): 1404,
#  ('dairy free coconut milk blueberry yogurt alternative',): 1405,
#  ('disinfecting wipes lemon',): 1405,
#  ('cannellini beans',): 1406,
#  ('100% whole wheat medium soft taco flour tortillas',): 1406,
#  ('organic iced green tea',): 1407,
#  ('fruit & nutty almonds raisins cranberries pecans granola',): 1407,
#  ('fat free plain yogurt',): 1407,
#  ('sensible foods kale veggie burgers - 4 ct',): 1407,
#  ('organic sweetened cranberries',): 1408,
#  ('muffins mini flax chocolate brownie',): 1409,
#  ('paper towels',): 1409,
#  ('vegan cheddar style cheese slices',): 1410,
#  ('plain better than cream cheese',): 1412,
#  ('organic baby romaine',): 1413,
#  ('semisweet chocolate chips',): 1413,
#  ('tomatillo',): 1413,
#  ('rosemary',): 1414,
#  ('diet coke soda',): 1414,
#  ('organic black mission figs',): 1414,
#  ('artichoke hearts',): 1415,
#  ('milk chocolate covered raisins',): 1415,
#  ('lemon cayenne agave cold pressed juice beverage',): 1416,
#  ('tesora medium roast',): 1416,
#  ('lime slim can',): 1416,
#  ('apples kale & avocados organic baby food',): 1419,
#  ('morning oat crunch',): 1419,
#  ('minneola tangelo',): 1419,
#  ('rainbow crisps fig and olive crackers',): 1420,
#  ('organic bagged mini milk peanut butter',): 1421,
#  ('grassfed whole milk plain yogurt',): 1421,
#  ('ultra strong toilet paper double rolls bathroom tissue',): 1421,
#  ('vanilla ice cream sandwich',): 1421,
#  ('gluten free quinoa pasta shells',): 1422,
#  ('easy open tabsbags',): 1422,
#  ('organic rice vinegar',): 1423,
#  ('coconut milk vanilla mini sandwiches',): 1423,
#  ('choose-a-sheet regular roll paper towels',): 1425,
#  ('organic original acai berry + guarana smoothie packs',): 1425,
#  ('limeade',): 1426,
#  ('plus lotion facial tissues',): 1426,
#  ('cinnamon',): 1427,
#  ('black bean vegetables burrito',): 1428,
#  ('1 ply paper towels',): 1429,
#  ('vanilla almond fit granola',): 1430,
#  ('green machine juice smoothie',): 1431,
#  ('natural apple sauce cups',): 1431,
#  ('gluten free pizza crust',): 1431,
#  ('chicken breast cutlets',): 1432,
#  ('organic stage 3 pear carrot apricot baby food',): 1432,
#  ('chicken tenders',): 1436,
#  ('eggo pancakes minis',): 1436,
#  ('whole wheat bunnies baked snack crackers',): 1436,
#  ('baby carrots',): 1436,
#  ('ice pops sugar free orange cherry grape',): 1437,
#  ('organic spelt tortillas',): 1438,
#  ('lemon-lime fridge pack soda',): 1439,
#  ('organic soy tempeh',): 1439,
#  ('vegan buttery sticks',): 1440,
#  ('orignial recipe chocolate pudding',): 1440,
#  ('gluten free pizza three cheese',): 1440,
#  ('fresh ciliegine mozzarella cheese',): 1440,
#  ('organic free range grade a large brown eggs',): 1441,
#  ('lemongrass & clementine zest natural dish liquid',): 1441,
#  ('truffle parmesan macaroni & cheese bowl',): 1442,
#  ('dark blackout organic chocolate',): 1442,
#  ('plastic wrap',): 1442,
#  ('organic avocados hass variety',): 1442,
#  ('vegetable tray with low fat dressing',): 1444,
#  ('organic campari cocktail tomatoes',): 1444,
#  ('apple apple applesauce on the go pouches',): 1445,
#  ('chicken tortilla soup',): 1445,
#  ('baby swiss slices cheese',): 1446,
#  ('fresh spinach',): 1446,
#  ('ruby red grapefruit',): 1447,
#  ('curate pomme baya-apple berry sparkling water',): 1448,
#  ('honey vanilla greek yogurt',): 1449,
#  ('red chile enchilada sauce',): 1449,
#  ('bag of large lemons',): 1449,
#  ('oh my yog! pacific coast strawberry trilayer yogurt',): 1450,
#  ('probugs whole milk kefir orange creamy crawler',): 1450,
#  ('mini blueberry muffins',): 1451,
#  ('strawberry puffs',): 1451,
#  ('original barbecue sauce',): 1453,
#  ('organic capellini',): 1453,
#  ('large eggs',): 1453,
#  ('organic ground black pepper',): 1454,
#  ('linguine pasta',): 1454,
#  ('almond milk hazelnut creamer',): 1454,
#  ('diet soda',): 1454,
#  ('pizza dough',): 1455,
#  ('organic multigrain with flax english muffins',): 1456,
#  ('stage 2 sweet potato corn & apple baby food',): 1457,
#  ('oragnic ginger lemon kombucha',): 1457,
#  ('organic ice cream vanilla bean',): 1459,
#  ('organic bagged valencia oranges',): 1459,
#  ('original cooking spray',): 1459,
#  ('single serve crispy wheat crackers',): 1460,
#  ('roasted garlic pasta sauce',): 1460,
#  ('jicama',): 1460,
#  ('peaches',): 1462,
#  ('pomegranate seeds',): 1462,
#  ('hard cooked eggs',): 1462,
#  ('banana & mango organic yogurt & fruit snacks\xa0',): 1462,
#  ('honest face hand & baby wipes',): 1462,
#  ('dry roasted almonds',): 1462,
#  ('asian chopped salad with dressing',): 1462,
#  ('100% oatnut bread',): 1462,
#  ('total 2% with raspberry pomegranate lowfat greek strained yogurt',): 1462,
#  ('sea salt brown rice crackers',): 1463,
#  ('whole wheat shells & white cheddar macaroni and cheese',): 1463,
#  ('turkey store lean ground turkey',): 1464,
#  ('coconut fruit bars',): 1464,
#  ('smoked apple sage sausages',): 1466,
#  ('instant oatmeal maple & brown sugar',): 1466,
#  ('envirokidz gluten free & wheat free gorilla munch corn puff cereal',): 1467,
#  ('stir-fry rice noodles',): 1467,
#  ('light and lean macaroni and cheese',): 1467,
#  ('yellow corn organic tortillas',): 1467,
#  ('whole chia seeds',): 1468,
#  ('olive bread',): 1468,
#  ('chives',): 1468,
#  ('all natural seasoned waffle cut fries',): 1469,
#  ('diet coke caffeine free soda',): 1469,
#  ('royal gala apples',): 1469,
#  ('rice krispies cereal',): 1469,
#  ('creamy deluxe macaroni dinner elbows & four cheese sauce',): 1470,
#  ('gluten free multi seed rice thin crackers',): 1470,
#  ('shelled edamame',): 1470,
#  ('traditional italian sauce',): 1470,
#  ('extra wide egg noodles',): 1472,
#  ('fresh dill',): 1473,
#  ('organic sweet potato puffs',): 1473,
#  ('high protein bar chunky peanut butter',): 1474,
#  ('country potato bread',): 1475,
#  ('classic meatless meatballs',): 1476,
#  ('maple almond butter',): 1477,
#  ('coconut water pure organic',): 1477,
#  ('thin spaghetti no 11',): 1478,
#  ('organic fiber & protein pear blueberry & spinach baby food',): 1480,
#  ('half baked frozen yogurt',): 1483,
#  ('california orange juice',): 1484,
#  ('organic fat free cottage cheese',): 1484,
#  ('carb balance flour tortillas',): 1485,
#  ('stage 1 - just prunes',): 1485,
#  ('chicken thighs',): 1485,
#  ('natural sour cream',): 1485,
#  ('sesame roasted seaweed snacks',): 1485,
#  ('organic quinoa dark chocolate bar',): 1486,
#  ('golean crisp! toasted berry crumble cereal',): 1486,
#  ('country cheddar bowl',): 1487,
#  ('organic vanilla chip chewy granola',): 1489,
#  ('the \\"world\'s best\\" veggie burger',): 1490,
#  ('mini peeled carrots',): 1490,
#  ('american cheese slices',): 1490,
#  ('rainier cherries',): 1492,
#  ('italian sausage',): 1492,
#  ('paprika',): 1492,
#  ('organic animal crackers',): 1494,
#  ('sunny days strawberry snack bars',): 1494,
#  ('organic brussel sprouts',): 1494,
#  ('organic turmeric',): 1495,
#  ('mediterranean vegetable chips',): 1495,
#  ('natural medium cheddar cheese',): 1496,
#  ('original french vanilla yogurt',): 1496,
#  ('vegetarian refried beans',): 1497,
#  ('pizza poppers uncured pepperoni',): 1497,
#  ('fat free french vanilla creamer',): 1498,
#  ('lemon lime thirst quencher',): 1498,
#  ('vegetarian organic golden corn',): 1499,
#  ('original life cereal',): 1504,
#  ('tomato yellow cherry',): 1505,
#  ('organic light in sodium lentil vegetable soup',): 1506,
#  ('real coconut water',): 1506,
#  ('mango sparkling water',): 1507,
#  ('sparkling grapefruit',): 1507,
#  ('sausage buns',): 1508,
#  ('organic banana blueberry baby food puree',): 1510,
#  ('organic extra large brown omega 3 eggs',): 1510,
#  ('70% dark chocolate salted almond bar',): 1510,
#  ('best cinnamon bread',): 1510,
#  ('organic peeled garlic',): 1512,
#  ('half and half ultra pasteurized',): 1514,
#  ('tempt unsweetened original hemp milk',): 1515,
#  ('first prunes',): 1515,
#  ('bay leaves',): 1515,
#  ('acai berry chia bar',): 1516,
#  ('phish food® ice cream',): 1516,
#  ('steamfresh sweet peas',): 1519,
#  ('ultra soft bathroom tissue double rolls',): 1520,
#  ('freshly made. filled with creamy ricotta aged parmesan and romano cheeses three cheese tortellini',): 1520,
#  ('organic graham crunch cereal',): 1520,
#  ('sorbet pops strawberry',): 1521,
#  ('wild caught frozen sockeye salmon fillet',): 1522,
#  ('whole grain loaf',): 1523,
#  ('corn tortilla chips',): 1525,
#  ('wild arugula',): 1526,
#  ("pirate's booty aged white cheddar baked rice and corn puffs",): 1526,
#  ('sweet italian chicken sausage',): 1528,
#  ('vitamin c super orange dietary supplement',): 1528,
#  ('ready-to-bake 9 inch pie crusts',): 1529,
#  ('100% natural tomato sauce',): 1530,
#  ('organic green peas',): 1532,
#  ('organic dandelion greens',): 1533,
#  ('peach-pear sparkling water',): 1534,
#  ('shredded 3 cheese blend',): 1535,
#  ('yellow soft corn tortillas 8 count',): 1535,
#  ('tomatillo salsa',): 1535,
#  ('baked snack crackers original',): 1538,
#  ('flourless  sprouted whole grain 7-sprouted grains english muffins',): 1539,
#  ('organic nonfat milk',): 1539,
#  ('total 0% cherry nonfat yogurt',): 1540,
#  ('made with organic beans & rice burrito non-dairy',): 1540,
#  ('honey dijon potato chips',): 1541,
#  ('cheese enchilada meal',): 1542,
#  ('organic whole wheat elbows',): 1542,
#  ('curly parsley bunch',): 1543,
#  ('organic black lentils',): 1543,
#  ('orange peel in dark chocolate bar',): 1543,
#  ('steamfresh premium selects broccoli florets',): 1544,
#  ...}

# %%
# Identify itemsets with minimum confidence level
rules = pyfpgrowth.generate_association_rules(patterns_all, 0.10)

# %%
rules
# Out:
# {('zero calorie cola',): (('soda',), 0.2229654403567447),
#  ('icelandic style skyr blueberry non-fat yogurt',): (('banana',),
#   0.1315947242206235),
#  ('non fat acai & mixed berries yogurt',): (('icelandic style skyr blueberry non-fat yogurt',),
#   0.24024550635686104),
#  ('organic yellow squash',): (('organic zucchini',), 0.22146274777853725),
#  ('apples',): (('clementines',), 0.16466973886328726),
#  ('organic nectarine',): (('organic strawberries',), 0.17563868613138686),
#  ('berry medley',): (('banana',), 0.1498446155924875),
#  ('total 2% all natural low fat 2% milkfat greek strained yogurt',): (('banana',),
#   0.1329130548988705),
#  ('total 0% nonfat plain greek yogurt',): (('banana',), 0.13606685818751632),
#  ('large yellow flesh nectarine',): (('banana',), 0.16987179487179488),
#  ('mini original babybel cheese',): (('banana',), 0.1305009511731135),
#  ('whole milk plain yogurt',): (('organic whole milk',), 0.13469336036492652),
#  ('vine ripe tomatoes',): (('banana',), 0.14532828282828283),
#  ('organic whole grassmilk milk',): (('bag of organic bananas',),
#   0.1303362296939932),
#  ('raisin bran cereal',): (('banana',), 0.12880009926789923),
#  ('xl emerald white seedless grapes',): (('banana',), 0.17936449515396885),
#  ('frozen broccoli florets',): (('banana',), 0.1506127450980392),
#  ('pretzel crisps original deli style pretzel crackers',): (('banana',),
#   0.1290361886194712),
#  ('spaghetti',): (('banana',), 0.1342665855143031),
#  ('2% reduced fat organic milk',): (('banana',), 0.13586827765932244),
#  ('total 2% lowfat plain greek yogurt',): (('banana',), 0.12943116240725475),
#  ('white onion',): (('banana',), 0.11940298507462686),
#  ('asparation/broccolini/baby broccoli',): (('banana',), 0.1886334757999307),
#  ('orange juice',): (('banana',), 0.1437105112004595),
#  ('organic beef hot dogs',): (('organic strawberries',), 0.11555249253388468),
#  ('sea salt pita chips',): (('banana',), 0.12457024982809993),
#  ('total 2% all natural plain greek yogurt',): (('banana',),
#   0.1262580054894785),
#  ('original veggie straws',): (('banana',), 0.12151869955666704),
#  ('spinach',): (('banana',), 0.13490629939038157),
#  ('globe eggplant',): (('organic zucchini',), 0.1196177627880832),
#  ('organic tomato basil pasta sauce',): (('banana',), 0.11292852341474345),
#  ('roasted red pepper hummus',): (('banana',), 0.11366666666666667),
#  ('organic snipped green beans',): (('bag of organic bananas',),
#   0.11170973062122046),
#  ('roasted turkey breast',): (('banana',), 0.11060059074499508),
#  ('organic low sodium chicken broth',): (('banana',), 0.11482939632545931),
#  ('shallot',): (('banana',), 0.11886813066754069),
#  ('organic baby spinach salad',): (('banana',), 0.11114725656039905),
#  ('ezekiel 4:9 bread organic sprouted whole grain',): (('banana',),
#   0.10936828534593898),
#  ('organic american cheese singles',): (('bag of organic bananas',),
#   0.11369950844197478),
#  ('organic baby kale',): (('organic baby spinach',), 0.10982842618089388),
#  ('organic broccoli crowns',): (('bag of organic bananas',),
#   0.14114177375184328),
#  ('european cucumber',): (('banana',), 0.12810265039966345),
#  ('chicken & maple breakfast sausage',): (('banana',), 0.10981749528005035),
#  ('organic mexican blend finely shredded cheese',): (('bag of organic bananas',),
#   0.12452987881320518),
#  ('organic shredded mozzarella',): (('bag of organic bananas',),
#   0.11684924360980699),
#  ('hass avocado',): (('banana',), 0.11004240355776192),
#  ('salted butter',): (('banana',), 0.12742914979757086),
#  ('original no pulp 100% florida orange juice',): (('banana',),
#   0.13530061226538193),
#  ('organic thyme',): (('organic garlic',), 0.10186286167261197),
#  ('organic mint',): (('limes',), 0.10064302416212004),
#  ('milk organic vitamin d',): (('bag of organic bananas',),
#   0.14323271665043816),
#  ('organic egg whites',): (('organic baby spinach',), 0.11732061143024049),
#  ('lemonade',): (('banana',), 0.10627126883811376),
#  ('organic butternut squash',): (('bag of organic bananas',),
#   0.10750388802488337),
#  ('organic frozen peas',): (('bag of organic bananas',), 0.12984252729204906),
#  ('marinara sauce',): (('banana',), 0.10314802411252512),
#  ('oven roasted turkey breast',): (('banana',), 0.11474004951437822),
#  ('organic yams',): (('banana',), 0.10931594860166288),
#  ('organic unsalted butter',): (('bag of organic bananas',),
#   0.11581512908467233),
#  ('large grapefruit',): (('banana',), 0.13309320126069338),
#  ('cherubs heavenly salad tomatoes',): (('banana',), 0.1257346393588602),
#  ('sour cream',): (('banana',), 0.10195208518189884),
#  ('boneless skinless chicken breast',): (('banana',), 0.12030644889712072),
#  ('gala apples',): (('banana',), 0.18322734499205087),
#  ('original orange juice',): (('banana',), 0.11715641261095806),
#  ('total 0% greek yogurt',): (('banana',), 0.14639722693413967),
#  ('total 0% nonfat greek yogurt',): (('banana',), 0.13476252345892883),
#  ('green onions',): (('banana',), 0.12070566388115135),
#  ('honey nut cheerios',): (('banana',), 0.13406546388076732),
#  ('russet potato',): (('banana',), 0.13508209589847583),
#  ('fat free milk',): (('banana',), 0.11587394793501664),
#  ('whole milk',): (('banana',), 0.12457310131728737),
#  ('2% reduced fat milk',): (('banana',), 0.12851260936695832),
#  ('bag of organic bananas', 'organic lemon'): (('organic hass avocado',),
#   0.1806901240863505),
#  ('organic hass avocado', 'organic lemon'): (('bag of organic bananas',),
#   0.19645167251894288),
#  ('organic hass avocado',
#   'organic strawberries'): (('bag of organic bananas',), 0.190095998479232),
#  ('organic raspberries', 'organic strawberries'): (('bag of organic bananas',),
#   0.17137391695735343),
#  ('bag of organic bananas', 'organic raspberries'): (('organic strawberries',),
#   0.1431794678950832),
#  ('banana', 'large lemon'): (('organic avocado',), 0.10731980929232494),
#  ('large lemon', 'organic avocado'): (('banana',), 0.17553516819571865),
#  ('organic avocado', 'organic strawberries'): (('banana',),
#   0.1801143583227446),
#  ('banana', 'organic avocado'): (('organic baby spinach',),
#   0.10210602759622367),
#  ('banana', 'organic baby spinach'): (('organic avocado',),
#   0.10417129732533155),
#  ('organic avocado', 'organic baby spinach'): (('banana',),
#   0.17298228346456693),
#  ('bag of organic bananas',
#   'organic baby spinach'): (('organic strawberries',), 0.10767933782955243),
#  ('organic baby spinach',
#   'organic hass avocado'): (('bag of organic bananas',), 0.18006103763987794),
#  ('bag of organic bananas',
#   'organic hass avocado'): (('organic strawberries',), 0.12287276525158199),
#  ('bag of organic bananas',
#   'organic strawberries'): (('organic hass avocado',), 0.12365524916532707)}

# %%
# Create a dataframe of frequent patterns and transpose the dataframe
df_rules = pd.DataFrame(rules).T

# %%
df_rules.head()
# Out:
#                                                                                                   0  \
# zero calorie cola                             NaN                                           (soda,)
# icelandic style skyr blueberry non-fat yogurt NaN                                         (banana,)
# non fat acai & mixed berries yogurt           NaN  (icelandic style skyr blueberry non-fat yogurt,)
# organic yellow squash                         NaN                               (organic zucchini,)
# apples                                        NaN                                    (clementines,)
#
#                                                           1
# zero calorie cola                             NaN  0.222965
# icelandic style skyr blueberry non-fat yogurt NaN  0.131595
# non fat acai & mixed berries yogurt           NaN  0.240246
# organic yellow squash                         NaN  0.221463
# apples                                        NaN   0.16467

# %%
# sort a dataframe in descending orders
df_rules_sorted = df_rules.sort_values(ascending = False, by = 1)

# %%
# reset index to display pair products
df_rules_sorted.reset_index(level = 0, inplace = True)

# %%
df_rules_sorted.reset_index(level = 0, inplace = True)

# %%
df_rules_sorted.head(2)
# Out:
#   index                              level_0  \
# 0   NaN  non fat acai & mixed berries yogurt
# 1   NaN                    zero calorie cola
#
#                                                   0         1
# 0  (icelandic style skyr blueberry non-fat yogurt,)  0.240246
# 1                                           (soda,)  0.222965

# %%
# rename columns to antecedent, consequents, and calculated confidence level
df_rules_sorted.rename(columns = {'index':'consequent_1','level_0':'consequent_2', 0:'antecedent', 1: 'confidence_level'}, inplace = True)

# %%
# take out brackets and commas in the consequent column
df_rules_sorted['antecedent'] = df_rules_sorted['antecedent'].astype(str).str.replace(r'\(|\)|,', '')
# reorder columns
cols = ['antecedent', 'consequent_1', 'consequent_2', 'confidence_level']
df_rules_sorted = df_rules_sorted.reindex(columns=cols)

# %%
df_rules_sorted.head()
# Out:
#                                         antecedent          consequent_1  \
# 0  'icelandic style skyr blueberry non-fat yogurt'                   NaN
# 1                                           'soda'                   NaN
# 2                               'organic zucchini'                   NaN
# 3                         'bag of organic bananas'         organic lemon
# 4                         'bag of organic bananas'  organic strawberries
#
#    consequent_2 confidence_level
# 0           NaN         0.240246
# 1           NaN         0.222965
# 2           NaN         0.221463
# 3           NaN         0.196452
# 4           NaN         0.190096

# %%
# save results to a .csv file in data folder
df_rules_sorted.to_csv('data/rules_50_percent.csv', index = False)
