# %% [markdown]
# #### Modeling and Analysis

# %%
import pandas as pd
import numpy as np
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
import random

# %%
# reading aisles dataset
aisles = pd.read_csv('data/aisles.csv')

# %%
# reading department dataset
department = pd.read_csv('data/departments.csv')

# %%
p = 0.05
all_orders = pd.read_csv('data/all_orders.csv', header = 0, skiprows = lambda i: i>0 and random.random() > p)

# %%
p = 0.30
morning_orders = pd.read_csv('data/morning_orders.csv', header = 0, skiprows = lambda i: i>0 and random.random() > p)

# %%
# create basket of products per order_id
basket_morning = (morning_orders
        .groupby(['order_id', 'product_name'])['quantity']
        .sum().unstack().reset_index().fillna(0)
        .set_index('order_id'))

# %%
basket_morning.shape
# Out:
# (6926, 4897)

# %%
# show a subset of columns
basket.iloc[:, [0, 1, 2, 3,4, 5, 6, 7]].head()
# Out:
# product_name  0% Fat Organic Greek Vanilla Yogurt  \
# order_id
# 254                                           0.0
# 275                                           0.0
# 456                                           0.0
# 775                                           0.0
# 1143                                          0.0
#
# product_name  0% Fat Strawberry Greek Yogurt  0% Greek Strained Yogurt  \
# order_id
# 254                                      0.0                       0.0
# 275                                      0.0                       0.0
# 456                                      0.0                       0.0
# 775                                      0.0                       0.0
# 1143                                     0.0                       0.0
#
# product_name  0% Greek Yogurt Black Cherry on the Bottom  \
# order_id
# 254                                                  0.0
# 275                                                  0.0
# ...

# %%
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

# %%
basket_morning_sets = basket_morning.applymap(encode_units)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-60-bfd89f767d5f> in <module>
# ----> 1 basket_morning_sets = basket_morning.applymap(encode_units)
#
# c:\users\anel akiyanova\anaconda3\envs\february\lib\site-packages\pandas\core\frame.py in applymap(self, func, na_action)
#    7839             return lib.map_infer(x.astype(object)._values, func, ignore_na=ignore_na)
#    7840
# -> 7841         return self.apply(infer).__finalize__(self, "applymap")
#    7842
#    7843     # ----------------------------------------------------------------------
#
# c:\users\anel akiyanova\anaconda3\envs\february\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7763             kwds=kwds,
#    7764         )
# -> 7765         return op.get_result()
#    7766
# ...

# %%
basket_sets.head()
# Out:
# product_name  0% Fat Organic Greek Vanilla Yogurt  \
# order_id
# 254                                             0
# 275                                             0
# 456                                             0
# 775                                             0
# 1143                                            0
#
# product_name  0% Fat Strawberry Greek Yogurt  0% Greek Strained Yogurt  \
# order_id
# 254                                        0                         0
# 275                                        0                         0
# 456                                        0                         0
# 775                                        0                         0
# 1143                                       0                         0
#
# product_name  0% Greek Yogurt Black Cherry on the Bottom  \
# order_id
# 254                                                    0
# 275                                                    0
# ...

# %%
frequent_itemsets = apriori(basket_morning_sets, min_support = 0.01, use_colnames = True)

# %%
frequent_itemsets.head()
# Out:
#     support                  itemsets
# 0  0.016186  (Bag of Organic Bananas)
# 1  0.016890                  (Banana)
# 2  0.011260    (Organic Strawberries)

# %%
# Create the rules
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=0.01)
rules
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction]
# Index: []

# %%
rules[ (rules['lift'] >= 6) &
       (rules['confidence'] >= 0.8) ]
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction]
# Index: []
