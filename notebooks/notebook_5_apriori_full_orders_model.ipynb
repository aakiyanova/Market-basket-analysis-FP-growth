# %% [markdown]
# #### Modeling and Analysis

# %%
import pandas as pd
import numpy as np
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
import random

# %%
# reading aisles dataset
aisles = pd.read_csv('data/aisles.csv')

# %%
# reading department dataset
department = pd.read_csv('data/departments.csv')

# %%
p = 0.01
all_orders = pd.read_csv('data/orders_train_prior.csv', header = 0, skiprows = lambda i: i>0 and random.random() > p)

# %%
all_orders.head(2)
# Out:
#    product_id                                    product_name  aisle_id  \
# 0          10  Sparkling Orange Juice & Prickly Pear Beverage       115
# 1          10  Sparkling Orange Juice & Prickly Pear Beverage       115
#
#    department_id  order_id  add_to_cart_order  reordered  quantity
# 0              7     50978                 12          0       1.0
# 1              7   1790235                 12          1       1.0

# %%
all_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30037 entries, 0 to 30036
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   product_id         30037 non-null  int64
#  1   product_name       30037 non-null  object
#  2   aisle_id           30037 non-null  int64
#  3   department_id      30037 non-null  int64
#  4   order_id           30037 non-null  int64
#  5   add_to_cart_order  30037 non-null  int64
#  6   reordered          30037 non-null  int64
#  7   quantity           30037 non-null  float64
# dtypes: float64(1), int64(6), object(1)
# memory usage: 1.8+ MB

# %%
# create basket of products per order_id
basket = (all_orders
        .groupby(['order_id', 'product_name'])['quantity']
        .sum().unstack().reset_index().fillna(0)
        .set_index('order_id'))

# %%
basket.shape
# Out:
# (28941, 9141)

# %%
# show a subset of columns
basket.iloc[:, [0, 1, 2, 3,4, 5, 6, 7]].head()
# Out:
# product_name  0 Calorie Fuji Apple Pear Water Beverage  \
# order_id
# 98                                                 0.0
# 112                                                0.0
# 125                                                0.0
# 344                                                0.0
# 359                                                0.0
#
# product_name  0% Fat Free Organic Milk  \
# order_id
# 98                                 0.0
# 112                                0.0
# 125                                0.0
# 344                                0.0
# 359                                0.0
#
# product_name  0% Fat Greek Yogurt Black Cherry on the Bottom  \
# order_id
# 98                                                       0.0
# 112                                                      0.0
# 125                                                      0.0
# 344                                                      0.0
# 359                                                      0.0
#
# product_name  0% Fat Organic Greek Vanilla Yogurt  0% Greek Strained Yogurt  \
# order_id
# 98                                            0.0                       0.0
# 112                                           0.0                       0.0
# 125                                           0.0                       0.0
# 344                                           0.0                       0.0
# 359                                           0.0                       0.0
#
# product_name  0% Greek Yogurt Black Cherry on the Bottom  \
# order_id
# 98                                                   0.0
# 112                                                  0.0
# 125                                                  0.0
# 344                                                  0.0
# 359                                                  0.0
#
# product_name  0% Greek, Blueberry on the Bottom Yogurt  1 % Lowfat Milk
# order_id
# 98                                                 0.0              0.0
# 112                                                0.0              0.0
# 125                                                0.0              0.0
# 344                                                0.0              0.0
# 359                                                0.0              0.0

# %%
# function to encode negative values
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

# %%
# apply function
basket_sets = basket.applymap(encode_units)

# %%
basket_sets.head()
# Out:
# product_name  0 Calorie Fuji Apple Pear Water Beverage  \
# order_id
# 98                                                   0
# 112                                                  0
# 125                                                  0
# 344                                                  0
# 359                                                  0
#
# product_name  0% Fat Free Organic Milk  \
# order_id
# 98                                   0
# 112                                  0
# 125                                  0
# 344                                  0
# 359                                  0
#
# product_name  0% Fat Greek Yogurt Black Cherry on the Bottom  \
# order_id
# 98                                                         0
# 112                                                        0
# 125                                                        0
# 344                                                        0
# 359                                                        0
#
# product_name  0% Fat Organic Greek Vanilla Yogurt  0% Greek Strained Yogurt  \
# order_id
# 98                                              0                         0
# 112                                             0                         0
# 125                                             0                         0
# 344                                             0                         0
# 359                                             0                         0
#
# product_name  0% Greek Yogurt Black Cherry on the Bottom  \
# order_id
# 98                                                     0
# 112                                                    0
# 125                                                    0
# 344                                                    0
# 359                                                    0
#
# product_name  0% Greek, Blueberry on the Bottom Yogurt  1 % Lowfat Milk  \
# order_id
# 98                                                   0                0
# 112                                                  0                0
# 125                                                  0                0
# 344                                                  0                0
# 359                                                  0                0
#
# product_name  1 Apple + 1 Mango Fruit Bar  1 Apple + 1 Pear Fruit Bar  ...  \
# order_id                                                               ...
# 98                                      0                           0  ...
# 112                                     0                           0  ...
# 125                                     0                           0  ...
# 344                                     0                           0  ...
# 359                                     0                           0  ...
#
# product_name  Zucchini Squash  \"Darn Good\" Chili Mix  \
# order_id
# 98                          0                        0
# 112                         0                        0
# 125                         0                        0
# 344                         0                        0
# 359                         0                        0
#
# product_name  \"Mokaccino\" Milk + Blue Bottle Coffee Chocolate  \
# order_id
# 98                                                            0
# 112                                                           0
# 125                                                           0
# 344                                                           0
# 359                                                           0
#
# product_name  by Mennen Power Antiperspirant/Deodorant Fresh  \
# order_id
# 98                                                         0
# 112                                                        0
# 125                                                        0
# 344                                                        0
# 359                                                        0
#
# product_name  for Tots Apple White Grape Juice  gel hand wash sea minerals  \
# order_id
# 98                                           0                           0
# 112                                          0                           0
# 125                                          0                           0
# 344                                          0                           0
# 359                                          0                           0
#
# product_name  smartwater® Electrolyte Enhanced Water  \
# order_id
# 98                                                 0
# 112                                                0
# 125                                                0
# 344                                                0
# 359                                                0
#
# product_name  vitaminwater® XXX Acai Blueberry Pomegranate  \
# order_id
# 98                                                       0
# 112                                                      0
# 125                                                      0
# 344                                                      0
# 359                                                      0
#
# product_name  with Crispy Almonds Cereal  \
# order_id
# 98                                     0
# 112                                    0
# 125                                    0
# 344                                    0
# 359                                    0
#
# product_name  with Dawn Action Pacs Fresh Scent Dishwasher Detergent Pacs
# order_id
# 98                                                            0
# 112                                                           0
# 125                                                           0
# 344                                                           0
# 359                                                           0
#
# [5 rows x 9141 columns]

# %%
frequent_itemsets = apriori(basket_sets, min_support = 0.01, use_colnames = True)

# %%
frequent_itemsets.head()
# Out:
#     support                    itemsets
# 0  0.001831    (100% Whole Wheat Bread)
# 1  0.001175       (2% Reduced Fat Milk)
# 2  0.002142  (Apple Honeycrisp Organic)
# 3  0.002591                 (Asparagus)
# 4  0.011403    (Bag of Organic Bananas)

# %%
frequent_itemsets = apriori(basket_sets, min_support = 0.001, use_colnames = True)
top_items = frequent_itemsets.sort_values('support', ascending = False)[:20]
for i in range(len(top_items.itemsets)):
    top_items.itemsets.iloc[i] = str(list(top_items.itemsets.iloc[i]))
fig = plt.figure(figsize = (10,10))
ax = fig.add_subplot(111)
ax.bar(top_items.itemsets, top_items.support)
for label in ax.xaxis.get_ticklabels():
    label.set_rotation(90)
plt.xlabel('Item')
plt.ylabel('Support');
# Out:
# c:\users\anel akiyanova\anaconda3\envs\february\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-fdb98fbacf2b> in <module>
#       3 for i in range(len(top_items.itemsets)):
#       4     top_items.itemsets.iloc[i] = str(list(top_items.itemsets.iloc[i]))
# ----> 5 fig = plt.figure(figsize = (10,10))
#       6 ax = fig.add_subplot(111)
#       7 ax.bar(top_items.itemsets, top_items.support)
#
# NameError: name 'plt' is not defined

# %%
# Create the rules
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=0.001)
rules
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction]
# Index: []

# %%
rules[ (rules['lift'] >= 6) &
       (rules['confidence'] >= 0.8) ]
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction]
# Index: []
