# %% [markdown]
# #### Modeling and Analysis

# %%
import pandas as pd
import numpy as np
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
import random

# %%
# reading aisles dataset
aisles = pd.read_csv('data/aisles.csv')

# %%
# reading department dataset
department = pd.read_csv('data/departments.csv')

# %%
p = 0.50
all_orders = pd.read_csv('data/all_orders.csv', header = 0, skiprows = lambda i: i>0 and random.random() > p)

# %%
all_orders.head(2)
# Out:
#    product_id                                       product_name  aisle_id  \
# 0         130  Vanilla Milk Chocolate Almond Ice Cream Bars M...        37
# 1         651                              Organic Salted Butter        36
#
#    department_id  order_id  add_to_cart_order  reordered  user_id eval_set  \
# 0              1    446766                 20          1   126093    train
# 1             16    446766                  4          1   126093    train
#
#    order_number  order_dow  order_hour_of_day  days_since_prior_order  \
# 0            58          4                 13                     5.0
# 1            58          4                 13                     5.0
#
#    quantity
# 0       1.0
# 1       1.0

# %%
# create basket of products per order_id
basket = (all_orders
        .groupby(['order_id', 'product_name'])['quantity']
        .sum().unstack().reset_index().fillna(0)
        .set_index('order_id'))
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-38-c065a250e01c> in <module>
#       1 # create basket of products per order_id
# ----> 2 basket = (all_orders
#       3         .groupby(['order_id', 'product_name'])['quantity']
#       4         .sum().unstack().reset_index().fillna(0)
#       5         .set_index('order_id'))
#
# c:\users\anel akiyanova\anaconda3\envs\february\lib\site-packages\pandas\core\frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    4966             new_obj = self
#    4967         else:
# -> 4968             new_obj = self.copy()
#    4969
#    4970         new_index = ibase.default_index(len(new_obj))
#
# c:\users\anel akiyanova\anaconda3\envs\february\lib\site-packages\pandas\core\generic.py in copy(self, deep)
#    5990         dtype: object
#    5991         """
# -> 5992         data = self._mgr.copy(deep=deep)
#    5993         self._clear_item_cache()
#    5994         return self._constructor(data).__finalize__(self, method="copy")
#
# c:\users\anel akiyanova\anaconda3\envs\february\lib\site-packages\pandas\core\internals\managers.py in copy(self, deep)
#     819             new_axes = list(self.axes)
#     820
# --> 821         res = self.apply("copy", deep=deep)
#     822         res.axes = new_axes
#     823         return res
#
# c:\users\anel akiyanova\anaconda3\envs\february\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     425                     applied = b.apply(f, **kwargs)
#     426                 else:
# --> 427                     applied = getattr(b, f)(**kwargs)
#     428             except (TypeError, NotImplementedError):
#     429                 if not ignore_failures:
#
# c:\users\anel akiyanova\anaconda3\envs\february\lib\site-packages\pandas\core\internals\blocks.py in copy(self, deep)
#     754         values = self.values
#     755         if deep:
# --> 756             values = values.copy()
#     757         return self.make_block_same_class(values, ndim=self.ndim)
#     758
#
# MemoryError: Unable to allocate 4.04 GiB for an array with shape (14254, 38003) and data type float64

# %%
basket.shape
# Out:
# (11040, 5840)

# %%
# show a subset of columns
basket.iloc[:, [0, 1, 2, 3,4, 5, 6, 7]].head()
# Out:
# product_name  & Go! Hazelnut Spread + Pretzel Sticks  \
# order_id
# 456                                              0.0
# 1198                                             0.0
# 1506                                             0.0
# 1591                                             0.0
# 2068                                             0.0
#
# product_name  0% Fat Free Organic Milk  0% Fat Organic Greek Vanilla Yogurt  \
# order_id
# 456                                0.0                                  0.0
# 1198                               0.0                                  0.0
# 1506                               0.0                                  0.0
# 1591                               0.0                                  0.0
# 2068                               0.0                                  0.0
#
# product_name  0% Fat Strawberry Greek Yogurt  0% Fat Vanilla Greek Yogurt  \
# order_id
# 456                                      0.0                          0.0
# 1198                                     0.0                          0.0
# 1506                                     0.0                          0.0
# 1591                                     0.0                          0.0
# 2068                                     0.0                          0.0
#
# product_name  0% Greek Strained Yogurt  \
# order_id
# 456                                0.0
# 1198                               0.0
# 1506                               0.0
# 1591                               0.0
# 2068                               0.0
#
# product_name  0% Greek Yogurt Black Cherry on the Bottom  1 % Lowfat Milk
# order_id
# 456                                                  0.0              0.0
# 1198                                                 0.0              0.0
# 1506                                                 0.0              0.0
# 1591                                                 0.0              0.0
# 2068                                                 0.0              0.0

# %%
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

# %%
basket_sets = basket.applymap(encode_units)

# %%
basket_sets.head()
# Out:
# product_name  & Go! Hazelnut Spread + Pretzel Sticks  \
# order_id
# 456                                                0
# 1198                                               0
# 1506                                               0
# 1591                                               0
# 2068                                               0
#
# product_name  0% Fat Free Organic Milk  0% Fat Organic Greek Vanilla Yogurt  \
# order_id
# 456                                  0                                    0
# 1198                                 0                                    0
# 1506                                 0                                    0
# 1591                                 0                                    0
# 2068                                 0                                    0
#
# product_name  0% Fat Strawberry Greek Yogurt  0% Fat Vanilla Greek Yogurt  \
# order_id
# 456                                        0                            0
# 1198                                       0                            0
# 1506                                       0                            0
# 1591                                       0                            0
# 2068                                       0                            0
#
# product_name  0% Greek Strained Yogurt  \
# order_id
# 456                                  0
# 1198                                 0
# 1506                                 0
# 1591                                 0
# 2068                                 0
#
# product_name  0% Greek Yogurt Black Cherry on the Bottom  1 % Lowfat Milk  \
# order_id
# 456                                                    0                0
# 1198                                                   0                0
# 1506                                                   0                0
# 1591                                                   0                0
# 2068                                                   0                0
#
# product_name  1 Apple + 1 Mango Fruit Bar  1 Liter  ...  Zesty Lemon Hommus  \
# order_id                                            ...
# 456                                     0        0  ...                   0
# 1198                                    0        0  ...                   0
# 1506                                    0        0  ...                   0
# 1591                                    0        0  ...                   0
# 2068                                    0        0  ...                   0
#
# product_name  Zinc 50 mg  Zinfandel  Zipper Sandwich Bags  Zucchini Noodles  \
# order_id
# 456                    0          0                     0                 0
# 1198                   0          0                     0                 0
# 1506                   0          0                     0                 0
# 1591                   0          0                     0                 0
# 2068                   0          0                     0                 0
#
# product_name  Zucchini Squash  \
# order_id
# 456                         0
# 1198                        0
# 1506                        0
# 1591                        0
# 2068                        0
#
# product_name  \"Constant Comment\" Decaffeinated Black Tea Blend  \
# order_id
# 456                                                           0
# 1198                                                          0
# 1506                                                          0
# 1591                                                          0
# 2068                                                          0
#
# product_name  of Hanover 100 Calorie Pretzels Mini  \
# order_id
# 456                                              0
# 1198                                             0
# 1506                                             0
# 1591                                             0
# 2068                                             0
#
# product_name  smartwater® Electrolyte Enhanced Water  \
# order_id
# 456                                                0
# 1198                                               0
# 1506                                               0
# 1591                                               0
# 2068                                               0
#
# product_name  with Crispy Almonds Cereal
# order_id
# 456                                    0
# 1198                                   0
# 1506                                   0
# 1591                                   0
# 2068                                   0
#
# [5 rows x 5840 columns]

# %%
frequent_itemsets = apriori(basket_sets, min_support = 0.05, use_colnames = True)

# %%
frequent_itemsets.head()
# Out:
# Empty DataFrame
# Columns: [support, itemsets]
# Index: []
