# %% [markdown]
# #### Modeling and Analysis

# %%
import pandas as pd
import numpy as np
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
import random

# %%
# reading aisles dataset
aisles = pd.read_csv('data/aisles.csv')

# %%
# reading department dataset
department = pd.read_csv('data/departments.csv')

# %%
p = 0.05
all_orders = pd.read_csv('data/all_orders.csv', header = 0, skiprows = lambda i: i>0 and random.random() > p)

# %%
all_orders.head(2)
# Out:
#    product_id                product_name  aisle_id  department_id  order_id  \
# 0       19123   Mini Lemon Pie Coco-Roons        61             19   2111270
# 1       25177  Sweet Toffee Milano Slices        61             19   2131981
#
#    add_to_cart_order  reordered  user_id eval_set  order_number  order_dow  \
# 0                 15          1    55877    train            21          0
# 1                 34          0    95547    train            26          5
#
#    order_hour_of_day  days_since_prior_order  quantity          aisle  \
# 0                 15                    26.0       1.0  cookies cakes
# 1                 10                     7.0       1.0  cookies cakes
#
#   department
# 0     snacks
# 1     snacks

# %%
# create basket of products per order_id
basket = (all_orders
        .groupby(['order_id', 'product_name'])['quantity']
        .sum().unstack().reset_index().fillna(0)
        .set_index('order_id'))

# %%
basket.shape
# Out:
# (6059, 3685)

# %%
# show a subset of columns
basket.iloc[:, [0, 1, 2, 3,4, 5, 6, 7]].head()
# Out:
# product_name  0% Fat Organic Greek Vanilla Yogurt  \
# order_id
# 254                                           0.0
# 275                                           0.0
# 456                                           0.0
# 775                                           0.0
# 1143                                          0.0
#
# product_name  0% Fat Strawberry Greek Yogurt  0% Greek Strained Yogurt  \
# order_id
# 254                                      0.0                       0.0
# 275                                      0.0                       0.0
# 456                                      0.0                       0.0
# 775                                      0.0                       0.0
# 1143                                     0.0                       0.0
#
# product_name  0% Greek Yogurt Black Cherry on the Bottom  \
# order_id
# 254                                                  0.0
# 275                                                  0.0
# 456                                                  0.0
# 775                                                  0.0
# 1143                                                 0.0
#
# product_name  1 Apple + 1 Mango Fruit Bar  1 Apple + 1 Pear Fruit Bar  \
# order_id
# 254                                   0.0                         0.0
# 275                                   0.0                         0.0
# 456                                   0.0                         0.0
# 775                                   0.0                         0.0
# 1143                                  0.0                         0.0
#
# product_name  1% Low Fat Milk  1% Lowfat Milk
# order_id
# 254                       0.0             0.0
# 275                       0.0             0.0
# 456                       0.0             0.0
# 775                       0.0             0.0
# 1143                      0.0             0.0

# %%
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

# %%
basket_sets = basket.applymap(encode_units)

# %%
basket_sets.head()
# Out:
# product_name  0% Fat Organic Greek Vanilla Yogurt  \
# order_id
# 254                                             0
# 275                                             0
# 456                                             0
# 775                                             0
# 1143                                            0
#
# product_name  0% Fat Strawberry Greek Yogurt  0% Greek Strained Yogurt  \
# order_id
# 254                                        0                         0
# 275                                        0                         0
# 456                                        0                         0
# 775                                        0                         0
# 1143                                       0                         0
#
# product_name  0% Greek Yogurt Black Cherry on the Bottom  \
# order_id
# 254                                                    0
# 275                                                    0
# 456                                                    0
# 775                                                    0
# 1143                                                   0
#
# product_name  1 Apple + 1 Mango Fruit Bar  1 Apple + 1 Pear Fruit Bar  \
# order_id
# 254                                     0                           0
# 275                                     0                           0
# 456                                     0                           0
# 775                                     0                           0
# 1143                                    0                           0
#
# product_name  1% Low Fat Milk  1% Lowfat Milk  1% Milkfat Low Fat Buttermilk  \
# order_id
# 254                         0               0                              0
# 275                         0               0                              0
# 456                         0               0                              0
# 775                         0               0                              0
# 1143                        0               0                              0
#
# product_name  1/3 Less Fat Cream Cheese  ...  \
# order_id                                 ...
# 254                                   0  ...
# 275                                   0  ...
# 456                                   0  ...
# 775                                   0  ...
# 1143                                  0  ...
#
# product_name  Zero Go-Go Mixed Berry Vitamin Water  \
# order_id
# 254                                              0
# 275                                              0
# 456                                              0
# 775                                              0
# 1143                                             0
#
# product_name  Zero Ion4 Grape Sports Drink  Zucchini Noodles  \
# order_id
# 254                                      0                 0
# 275                                      0                 0
# 456                                      0                 0
# 775                                      0                 0
# 1143                                     0                 0
#
# product_name  Zucchini Soufflé  Zucchini Squash  \
# order_id
# 254                          0                0
# 275                          0                0
# 456                          0                0
# 775                          0                0
# 1143                         0                0
#
# product_name  \"Mokaccino\" Milk + Blue Bottle Coffee Chocolate  \
# order_id
# 254                                                           0
# 275                                                           0
# 456                                                           0
# 775                                                           0
# 1143                                                          0
#
# product_name  gel hand wash sea minerals  \
# order_id
# 254                                    0
# 275                                    0
# 456                                    0
# 775                                    0
# 1143                                   0
#
# product_name  smartwater® Electrolyte Enhanced Water  \
# order_id
# 254                                                0
# 275                                                0
# 456                                                0
# 775                                                0
# 1143                                               0
#
# product_name  with Olive Oil Mayonnaise Dressing  \
# order_id
# 254                                            0
# 275                                            0
# 456                                            0
# 775                                            0
# 1143                                           0
#
# product_name  with a Splash of Mango Coconut Water
# order_id
# 254                                              0
# 275                                              0
# 456                                              0
# 775                                              0
# 1143                                             0
#
# [5 rows x 3685 columns]

# %%
frequent_itemsets = apriori(basket_sets, min_support = 0.01, use_colnames = True)

# %%
frequent_itemsets.head()
# Out:
#     support                  itemsets
# 0  0.013369  (Bag of Organic Bananas)
# 1  0.015514                  (Banana)

# %%
# Create the rules
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=0.01)
rules
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction]
# Index: []

# %%
rules[ (rules['lift'] >= 6) &
       (rules['confidence'] >= 0.8) ]
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction]
# Index: []
